# %%
import sys
import os
import warnings
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
warnings.filterwarnings("ignore")

# %%
from src.database.db_connection import *
from src.database.preparation import *
from src.utilities.step1_simplify_fds import *
from src.utilities.step2_clustering_and_generating_repairs import *
from src.utilities.step3_convert_back_to_db import *
from src.utilities.step4_group_similar_sentences import *
from src.evaluation.metrics import *
from src.database.db_connection import *

# %%
engine = create_engine_for_db()

# %%
fd_constraints = [(['sid', 'university'],['sname', 'address', 'postcode', 'emailid', 'phonenum'])]

# %%
fd_constraints = simplify_FDs(fd_constraints)

# %%
fd_constraints
# Out:
# [(['sid', 'university'], ['sname']),
#  (['sid', 'university'], ['address']),
#  (['sid', 'university'], ['postcode']),
#  (['sid', 'university'], ['emailid']),
#  (['sid', 'university'], ['phonenum'])]

# %%
violation_levels = [
  {'target_violation_fraction': 0.20, 'dups_per_cluster': (1, 1),  'cells_corrupted': (1, 1)},
  {'target_violation_fraction': 0.40, 'dups_per_cluster': (3, 3),  'cells_corrupted': (1, 2)},  
  {'target_violation_fraction': 0.60, 'dups_per_cluster': (6, 6),  'cells_corrupted': (2, 3)},  
  {'target_violation_fraction': 0.80, 'dups_per_cluster': (9, 9),  'cells_corrupted': (3, 4)}  
]

num_inconsistent_relations = 20

delete_cost = 2
update_cost = 1
eps=1e-9
prob_type = 'COST_BASED'
constraint_hardness = [1.0] * len(fd_constraints)

query_file_name_expected_Prob = "../../../queries/FP/synthetic/Students_truth.sql"
query_file_name_actual_Prob = "../../../queries/FP/synthetic/Students_prob.sql"
algorithm_name = 'PRA'
old_table_name = ''
new_table_name = ''

# %%
for j,violation_level in enumerate(violation_levels,start=1):
    total_time = 0.0
    total_precision_prob, total_recall_prob,total_coverage_prob, total_noise_prob = 0.0, 0.0, 0.0, 0.0
    total_rvs = 0
    total_cartesian_possible = 0
    total_cartesian_computed = 0
    min_cost_actions_suggested = 0
    
    target_violation_fraction = violation_level['target_violation_fraction']
    dups_per_cluster = violation_level['dups_per_cluster']
    cells_corrupted = violation_level['cells_corrupted']
    
    for i in range(1, num_inconsistent_relations + 1):
        
        table_name = f"students_{j}_{i}"
        inconsistent_df = pd.read_sql_table(table_name, con=engine, schema="prototype_fp")
        with engine.begin() as connection:
            connection.execute(text("""
            TRUNCATE TABLE prototype_fp.students_prob
            RESTART IDENTITY
            CASCADE;
            """))
            connection.execute(text("""
            UPDATE prototype_fp."_dict"
            SET dict = dictionary('')
            WHERE name = :name;
            """), {"name": "students_dict"})
            

        start = time.perf_counter()
        inconsistent_df = preprocess_data(inconsistent_df)
        actions,cluster_ids,rv_probs = compute_actions(inconsistent_df, fd_constraints, constraint_hardness,delete_cost, update_cost,eps,prob_type)
        all_actions,cartesian_possible,cartesian_computed = min_cost_actions_pruned(cluster_ids,actions,delete_cost,update_cost)
        
        total_cartesian_possible += cartesian_possible
        total_cartesian_computed += cartesian_computed
        min_cost_actions_suggested += len(all_actions)
        
        repaired_versions =  apply_combined_actions(inconsistent_df, all_actions, uuid_col="uuid")
        repaired_versions = pd.concat(repaired_versions, ignore_index=True)
        repaired_versions = repaired_versions.drop(columns=["uuid"])
        rv_probabilities = filter_and_condition_min_cost_rvs(rv_probs, repaired_versions)
        repaired_df = group_similar_rows_together(repaired_versions)

        repaired_df.to_sql('students_prob',engine,schema='prototype_fp',index=False,if_exists='append')
        entries = [f"{k}:{v}" for k, v in rv_probabilities.items()]
        joined = ';'.join(entries)

        update_stmt = f"UPDATE prototype_fp._dict\nSET dict=add(dict, '{joined}')\nWHERE name='students_dict';"
        with engine.begin() as connection:
            connection.execute(text(update_stmt))
        elapsed = time.perf_counter() - start
        total_rvs += len(rv_probabilities)
        total_time += elapsed

        results_Prob,results_with_truth_set_prob = calculate_expected_values(query_file_name_expected_Prob, query_file_name_actual_Prob, algorithm_name,
                                                                             engine,old_table_name,new_table_name)
        precision_prob, recall_prob,coverage_prob, noise_prob = summarize_results(results_Prob)

        print(f"\nViolation Level {j}: Processed inconsistent relation {i} table name: {table_name}")
        print(f"Time taken {elapsed}")
        print(f"Number of RVs used {int(len(rv_probabilities))}")
        print(f"Possible Repair Actions (cartesian product) {int(cartesian_possible)}")
        print(f"Computed Repair Actions {int(cartesian_computed)}")
        print(f"Min cost Repair Actions suggested {int(len(all_actions))}")
        print(f"Precision Probabilistic: {precision_prob:.4f}")
        print(f"Recall Probabilistic: {recall_prob:.4f}")
        print(f"Coverage Probabilistic: {coverage_prob:.4f}")
        print(f"Noise Probabilistic: {noise_prob:.4f}")
        total_precision_prob += precision_prob
        total_recall_prob += recall_prob
        total_coverage_prob += coverage_prob
        total_noise_prob += noise_prob
    
    avg_time_violation_level = total_time/num_inconsistent_relations
    avg_number_of_rvs = total_rvs/num_inconsistent_relations
    avg_max_repair_actions_possible = total_cartesian_possible/num_inconsistent_relations
    avg_max_repair_actions_computed = total_cartesian_computed/num_inconsistent_relations
    avg_min_cost_actions_suggested = min_cost_actions_suggested/num_inconsistent_relations
    avg_precision_prob = total_precision_prob / num_inconsistent_relations
    avg_recall_prob = total_recall_prob / num_inconsistent_relations
    avg_coverage_prob = total_coverage_prob / num_inconsistent_relations
    avg_noise_prob = total_noise_prob / num_inconsistent_relations

    
    print(f"\nViolation Level {j}: Average time taken {avg_time_violation_level}")
    print(f"Violation Level {j}: Average number of RVs used {int(avg_number_of_rvs)}")
    print(f"Violation Level {j}: Average Max possible repair actions {int(avg_max_repair_actions_possible)}")
    print(f"Violation Level {j}: Average Max computed repair actions {int(avg_max_repair_actions_computed)}")
    print(f"Violation Level {j}: Min cost repair actions suggested {int(avg_min_cost_actions_suggested)}")
    print(f"Average Precision Probabilistic for violation level {j}: {avg_precision_prob:.4f}")
    print(f"Average Recall Probabilistic for violation level {j}: {avg_recall_prob:.4f}")
    print(f"Average Coverage Probabilistic for violation level {j}: {avg_coverage_prob:.4f}")
    print(f"Average Noise Probabilistic for violation level {j}: {avg_noise_prob:.4f}")
# Out:
# Violation Level 1: Processed inconsistent relation 1 table name: students_1_1
# Time taken 0.12485989998094738
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9396
# Recall Probabilistic: 0.9244
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0604
#
# Violation Level 1: Processed inconsistent relation 2 table name: students_1_2
# Time taken 0.12638510001124814
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9385
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0615
#
# Violation Level 1: Processed inconsistent relation 3 table name: students_1_3
# Time taken 0.1277917999541387
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9375
# Recall Probabilistic: 0.9222
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0625
#
# Violation Level 1: Processed inconsistent relation 4 table name: students_1_4
# Time taken 0.11350099998526275
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9252
# Recall Probabilistic: 0.9051
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0748
#
# Violation Level 1: Processed inconsistent relation 5 table name: students_1_5
# Time taken 0.11677320004673675
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9325
# Recall Probabilistic: 0.9504
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0675
#
# Violation Level 1: Processed inconsistent relation 6 table name: students_1_6
# Time taken 0.12396629998693243
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9385
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0615
#
# Violation Level 1: Processed inconsistent relation 7 table name: students_1_7
# Time taken 0.10802430001785979
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9375
# Recall Probabilistic: 0.9222
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0625
#
# Violation Level 1: Processed inconsistent relation 8 table name: students_1_8
# Time taken 0.10009960003662854
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9378
# Recall Probabilistic: 0.9622
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0622
#
# Violation Level 1: Processed inconsistent relation 9 table name: students_1_9
# Time taken 0.1212818999774754
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9380
# Recall Probabilistic: 0.9611
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0620
#
# Violation Level 1: Processed inconsistent relation 10 table name: students_1_10
# Time taken 0.12390690000029281
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9375
# Recall Probabilistic: 0.9222
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0625
#
# Violation Level 1: Processed inconsistent relation 11 table name: students_1_11
# Time taken 0.11576319998130202
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9387
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0613
#
# Violation Level 1: Processed inconsistent relation 12 table name: students_1_12
# Time taken 0.15911579999374226
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9325
# Recall Probabilistic: 0.9504
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0675
#
# Violation Level 1: Processed inconsistent relation 13 table name: students_1_13
# Time taken 0.11778679996496066
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9385
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0615
#
# Violation Level 1: Processed inconsistent relation 14 table name: students_1_14
# Time taken 0.10576169996056706
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9338
# Recall Probabilistic: 0.9137
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0662
#
# Violation Level 1: Processed inconsistent relation 15 table name: students_1_15
# Time taken 0.12775670003611594
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9385
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0615
#
# Violation Level 1: Processed inconsistent relation 16 table name: students_1_16
# Time taken 0.11597909999545664
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9385
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0615
#
# Violation Level 1: Processed inconsistent relation 17 table name: students_1_17
# Time taken 0.11712700000498444
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9338
# Recall Probabilistic: 0.9137
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0662
#
# Violation Level 1: Processed inconsistent relation 18 table name: students_1_18
# Time taken 0.1629339000210166
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9385
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0615
#
# Violation Level 1: Processed inconsistent relation 19 table name: students_1_19
# Time taken 0.09067180001875386
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9338
# Recall Probabilistic: 0.9137
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0662
#
# Violation Level 1: Processed inconsistent relation 20 table name: students_1_20
# Time taken 0.10810020001372322
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9387
# Recall Probabilistic: 0.9233
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0613
#
# Violation Level 1: Average time taken 0.12037930999940727
# Violation Level 1: Average number of RVs used 3
# Violation Level 1: Average Max possible repair actions 3
# Violation Level 1: Average Max computed repair actions 3
# Violation Level 1: Min cost repair actions suggested 3
# Average Precision Probabilistic for violation level 1: 0.9364
# Average Recall Probabilistic for violation level 1: 0.9274
# Average Coverage Probabilistic for violation level 1: 1.0000
# Average Noise Probabilistic for violation level 1: 0.0636
#
# Violation Level 2: Processed inconsistent relation 1 table name: students_2_1
# Time taken 0.1494855000055395
# Number of RVs used 14
# Possible Repair Actions (cartesian product) 304
# Computed Repair Actions 45
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8828
# Recall Probabilistic: 0.9849
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1172
#
# Violation Level 2: Processed inconsistent relation 2 table name: students_2_2
# Time taken 0.2822525999508798
# Number of RVs used 17
# Possible Repair Actions (cartesian product) 176
# Computed Repair Actions 40
# Min cost Repair Actions suggested 10
# Precision Probabilistic: 0.8255
# Recall Probabilistic: 0.8702
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1745
#
# Violation Level 2: Processed inconsistent relation 3 table name: students_2_3
# Time taken 0.14983870001742616
# Number of RVs used 13
# Possible Repair Actions (cartesian product) 249
# Computed Repair Actions 34
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9505
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0495
#
# Violation Level 2: Processed inconsistent relation 4 table name: students_2_4
# Time taken 0.2755475000012666
# Number of RVs used 22
# Possible Repair Actions (cartesian product) 1240
# Computed Repair Actions 188
# Min cost Repair Actions suggested 23
# Precision Probabilistic: 0.8624
# Recall Probabilistic: 0.8177
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1376
#
# Violation Level 2: Processed inconsistent relation 5 table name: students_2_5
# Time taken 0.18309250002494082
# Number of RVs used 20
# Possible Repair Actions (cartesian product) 272
# Computed Repair Actions 42
# Min cost Repair Actions suggested 12
# Precision Probabilistic: 0.9052
# Recall Probabilistic: 0.9060
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0948
#
# Violation Level 2: Processed inconsistent relation 6 table name: students_2_6
# Time taken 0.21541800000704825
# Number of RVs used 19
# Possible Repair Actions (cartesian product) 4244
# Computed Repair Actions 261
# Min cost Repair Actions suggested 13
# Precision Probabilistic: 0.8524
# Recall Probabilistic: 0.8825
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1476
#
# Violation Level 2: Processed inconsistent relation 7 table name: students_2_7
# Time taken 0.15776589995948598
# Number of RVs used 12
# Possible Repair Actions (cartesian product) 104
# Computed Repair Actions 24
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8175
# Recall Probabilistic: 0.9096
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.1825
#
# Violation Level 2: Processed inconsistent relation 8 table name: students_2_8
# Time taken 0.20832989999325946
# Number of RVs used 17
# Possible Repair Actions (cartesian product) 1592
# Computed Repair Actions 129
# Min cost Repair Actions suggested 10
# Precision Probabilistic: 0.8897
# Recall Probabilistic: 0.9553
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1103
#
# Violation Level 2: Processed inconsistent relation 9 table name: students_2_9
# Time taken 0.3099606999894604
# Number of RVs used 22
# Possible Repair Actions (cartesian product) 1872
# Computed Repair Actions 167
# Min cost Repair Actions suggested 14
# Precision Probabilistic: 0.8846
# Recall Probabilistic: 0.9224
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1154
#
# Violation Level 2: Processed inconsistent relation 10 table name: students_2_10
# Time taken 0.32410989998606965
# Number of RVs used 31
# Possible Repair Actions (cartesian product) 4928
# Computed Repair Actions 423
# Min cost Repair Actions suggested 25
# Precision Probabilistic: 0.9167
# Recall Probabilistic: 0.8216
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0833
#
# Violation Level 2: Processed inconsistent relation 11 table name: students_2_11
# Time taken 0.18201699998462573
# Number of RVs used 18
# Possible Repair Actions (cartesian product) 522
# Computed Repair Actions 74
# Min cost Repair Actions suggested 10
# Precision Probabilistic: 0.9293
# Recall Probabilistic: 0.9472
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0707
#
# Violation Level 2: Processed inconsistent relation 12 table name: students_2_12
# Time taken 0.19130870001390576
# Number of RVs used 19
# Possible Repair Actions (cartesian product) 280
# Computed Repair Actions 42
# Min cost Repair Actions suggested 9
# Precision Probabilistic: 0.8690
# Recall Probabilistic: 0.9572
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1310
#
# Violation Level 2: Processed inconsistent relation 13 table name: students_2_13
# Time taken 0.17446320003364235
# Number of RVs used 14
# Possible Repair Actions (cartesian product) 580
# Computed Repair Actions 85
# Min cost Repair Actions suggested 9
# Precision Probabilistic: 0.9068
# Recall Probabilistic: 0.9310
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0932
#
# Violation Level 2: Processed inconsistent relation 14 table name: students_2_14
# Time taken 0.15801779995672405
# Number of RVs used 14
# Possible Repair Actions (cartesian product) 100
# Computed Repair Actions 20
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8994
# Recall Probabilistic: 0.9844
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1006
#
# Violation Level 2: Processed inconsistent relation 15 table name: students_2_15
# Time taken 0.1495026999618858
# Number of RVs used 10
# Possible Repair Actions (cartesian product) 25
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.8651
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1349
#
# Violation Level 2: Processed inconsistent relation 16 table name: students_2_16
# Time taken 0.15832139999838546
# Number of RVs used 16
# Possible Repair Actions (cartesian product) 172
# Computed Repair Actions 40
# Min cost Repair Actions suggested 10
# Precision Probabilistic: 0.8848
# Recall Probabilistic: 0.9466
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1152
#
# Violation Level 2: Processed inconsistent relation 17 table name: students_2_17
# Time taken 0.18289159995038062
# Number of RVs used 20
# Possible Repair Actions (cartesian product) 272
# Computed Repair Actions 59
# Min cost Repair Actions suggested 13
# Precision Probabilistic: 0.8111
# Recall Probabilistic: 0.8793
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1889
#
# Violation Level 2: Processed inconsistent relation 18 table name: students_2_18
# Time taken 0.15557950001675636
# Number of RVs used 15
# Possible Repair Actions (cartesian product) 328
# Computed Repair Actions 45
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.9259
# Recall Probabilistic: 0.9375
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0741
#
# Violation Level 2: Processed inconsistent relation 19 table name: students_2_19
# Time taken 0.19128900003852323
# Number of RVs used 19
# Possible Repair Actions (cartesian product) 184
# Computed Repair Actions 48
# Min cost Repair Actions suggested 12
# Precision Probabilistic: 0.8563
# Recall Probabilistic: 0.8770
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1437
#
# Violation Level 2: Processed inconsistent relation 20 table name: students_2_20
# Time taken 0.21552090003388003
# Number of RVs used 22
# Possible Repair Actions (cartesian product) 1872
# Computed Repair Actions 181
# Min cost Repair Actions suggested 14
# Precision Probabilistic: 0.8963
# Recall Probabilistic: 0.9150
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1037
#
# Violation Level 2: Average time taken 0.2007356499962043
# Violation Level 2: Average number of RVs used 17
# Violation Level 2: Average Max possible repair actions 965
# Violation Level 2: Average Max computed repair actions 97
# Violation Level 2: Min cost repair actions suggested 10
# Average Precision Probabilistic for violation level 2: 0.8816
# Average Recall Probabilistic for violation level 2: 0.9223
# Average Coverage Probabilistic for violation level 2: 0.9939
# Average Noise Probabilistic for violation level 2: 0.1184
#
# Violation Level 3: Processed inconsistent relation 1 table name: students_3_1
# Time taken 3.3329246999928728
# Number of RVs used 39
# Possible Repair Actions (cartesian product) 25980544
# Computed Repair Actions 15320
# Min cost Repair Actions suggested 19
# Precision Probabilistic: 0.7498
# Recall Probabilistic: 0.9886
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2502
#
# Violation Level 3: Processed inconsistent relation 2 table name: students_3_2
# Time taken 3.634550600021612
# Number of RVs used 41
# Possible Repair Actions (cartesian product) 13549600
# Computed Repair Actions 17915
# Min cost Repair Actions suggested 21
# Precision Probabilistic: 0.7820
# Recall Probabilistic: 0.8804
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2180
#
# Violation Level 3: Processed inconsistent relation 3 table name: students_3_3
# Time taken 3.192002499999944
# Number of RVs used 42
# Possible Repair Actions (cartesian product) 13677888
# Computed Repair Actions 14853
# Min cost Repair Actions suggested 24
# Precision Probabilistic: 0.7473
# Recall Probabilistic: 0.8457
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2527
#
# Violation Level 3: Processed inconsistent relation 4 table name: students_3_4
# Time taken 3.5328481000033207
# Number of RVs used 44
# Possible Repair Actions (cartesian product) 26102912
# Computed Repair Actions 16063
# Min cost Repair Actions suggested 21
# Precision Probabilistic: 0.7399
# Recall Probabilistic: 0.9069
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2601
#
# Violation Level 3: Processed inconsistent relation 5 table name: students_3_5
# Time taken 3.6566147000412457
# Number of RVs used 46
# Possible Repair Actions (cartesian product) 7230464
# Computed Repair Actions 17670
# Min cost Repair Actions suggested 24
# Precision Probabilistic: 0.7500
# Recall Probabilistic: 0.9335
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2500
#
# Violation Level 3: Processed inconsistent relation 6 table name: students_3_6
# Time taken 1.3907713000080548
# Number of RVs used 34
# Possible Repair Actions (cartesian product) 1843200
# Computed Repair Actions 5006
# Min cost Repair Actions suggested 14
# Precision Probabilistic: 0.8047
# Recall Probabilistic: 0.7874
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1953
#
# Violation Level 3: Processed inconsistent relation 7 table name: students_3_7
# Time taken 3.0251687999698333
# Number of RVs used 43
# Possible Repair Actions (cartesian product) 3788800
# Computed Repair Actions 16553
# Min cost Repair Actions suggested 29
# Precision Probabilistic: 0.7298
# Recall Probabilistic: 0.9141
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2702
#
# Violation Level 3: Processed inconsistent relation 8 table name: students_3_8
# Time taken 3.782736199966166
# Number of RVs used 41
# Possible Repair Actions (cartesian product) 13361280
# Computed Repair Actions 19577
# Min cost Repair Actions suggested 22
# Precision Probabilistic: 0.7601
# Recall Probabilistic: 0.9277
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2399
#
# Violation Level 3: Processed inconsistent relation 9 table name: students_3_9
# Time taken 2.983901900006458
# Number of RVs used 43
# Possible Repair Actions (cartesian product) 13255808
# Computed Repair Actions 15364
# Min cost Repair Actions suggested 25
# Precision Probabilistic: 0.7540
# Recall Probabilistic: 0.8369
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2460
#
# Violation Level 3: Processed inconsistent relation 10 table name: students_3_10
# Time taken 6.423752600036096
# Number of RVs used 43
# Possible Repair Actions (cartesian product) 64287744
# Computed Repair Actions 32422
# Min cost Repair Actions suggested 25
# Precision Probabilistic: 0.7339
# Recall Probabilistic: 0.8304
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2661
#
# Violation Level 3: Processed inconsistent relation 11 table name: students_3_11
# Time taken 3.931680999987293
# Number of RVs used 46
# Possible Repair Actions (cartesian product) 2343564
# Computed Repair Actions 17480
# Min cost Repair Actions suggested 43
# Precision Probabilistic: 0.6892
# Recall Probabilistic: 0.7734
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.3108
#
# Violation Level 3: Processed inconsistent relation 12 table name: students_3_12
# Time taken 5.441113999986555
# Number of RVs used 50
# Possible Repair Actions (cartesian product) 13589632
# Computed Repair Actions 26165
# Min cost Repair Actions suggested 29
# Precision Probabilistic: 0.7521
# Recall Probabilistic: 0.6800
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2479
#
# Violation Level 3: Processed inconsistent relation 13 table name: students_3_13
# Time taken 3.182535900035873
# Number of RVs used 43
# Possible Repair Actions (cartesian product) 4300928
# Computed Repair Actions 15649
# Min cost Repair Actions suggested 28
# Precision Probabilistic: 0.7714
# Recall Probabilistic: 0.8843
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2286
#
# Violation Level 3: Processed inconsistent relation 14 table name: students_3_14
# Time taken 4.0405312000075355
# Number of RVs used 40
# Possible Repair Actions (cartesian product) 27205632
# Computed Repair Actions 18334
# Min cost Repair Actions suggested 20
# Precision Probabilistic: 0.7668
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2332
#
# Violation Level 3: Processed inconsistent relation 15 table name: students_3_15
# Time taken 34.706649100000504
# Number of RVs used 53
# Possible Repair Actions (cartesian product) 366775296
# Computed Repair Actions 234719
# Min cost Repair Actions suggested 86
# Precision Probabilistic: 0.7683
# Recall Probabilistic: 0.8163
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2317
#
# Violation Level 3: Processed inconsistent relation 16 table name: students_3_16
# Time taken 1.1245716999983415
# Number of RVs used 39
# Possible Repair Actions (cartesian product) 542272
# Computed Repair Actions 4503
# Min cost Repair Actions suggested 22
# Precision Probabilistic: 0.7183
# Recall Probabilistic: 0.8784
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2817
#
# Violation Level 3: Processed inconsistent relation 17 table name: students_3_17
# Time taken 3.283484000014141
# Number of RVs used 47
# Possible Repair Actions (cartesian product) 6678080
# Computed Repair Actions 17211
# Min cost Repair Actions suggested 32
# Precision Probabilistic: 0.7032
# Recall Probabilistic: 0.9220
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2968
#
# Violation Level 3: Processed inconsistent relation 18 table name: students_3_18
# Time taken 0.7674740999937057
# Number of RVs used 41
# Possible Repair Actions (cartesian product) 303232
# Computed Repair Actions 3604
# Min cost Repair Actions suggested 17
# Precision Probabilistic: 0.7169
# Recall Probabilistic: 0.9151
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2831
#
# Violation Level 3: Processed inconsistent relation 19 table name: students_3_19
# Time taken 2.9237460999866016
# Number of RVs used 43
# Possible Repair Actions (cartesian product) 3483840
# Computed Repair Actions 15921
# Min cost Repair Actions suggested 24
# Precision Probabilistic: 0.7251
# Recall Probabilistic: 0.8292
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2749
#
# Violation Level 3: Processed inconsistent relation 20 table name: students_3_20
# Time taken 5.699837499996647
# Number of RVs used 50
# Possible Repair Actions (cartesian product) 27488256
# Computed Repair Actions 27955
# Min cost Repair Actions suggested 29
# Precision Probabilistic: 0.7396
# Recall Probabilistic: 0.7857
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2604
#
# Violation Level 3: Average time taken 5.00284480000264
# Violation Level 3: Average number of RVs used 43
# Violation Level 3: Average Max possible repair actions 31789448
# Violation Level 3: Average Max computed repair actions 27614
# Violation Level 3: Min cost repair actions suggested 27
# Average Precision Probabilistic for violation level 3: 0.7451
# Average Recall Probabilistic for violation level 3: 0.8668
# Average Coverage Probabilistic for violation level 3: 0.9969
# Average Noise Probabilistic for violation level 3: 0.2549
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 33
#      31 inconsistent_df = preprocess_data(inconsistent_df)
#      32 actions,cluster_ids,rv_probs = compute_actions(inconsistent_df, fd_constraints, constraint_hardness,delete_cost, update_cost,eps,prob_type)
# ---> 33 all_actions,cartesian_possible,cartesian_computed = min_cost_actions_pruned(cluster_ids,actions,delete_cost,update_cost)
#      35 total_cartesian_possible += cartesian_possible
#      36 total_cartesian_computed += cartesian_computed
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:614, in min_cost_actions_pruned(cluster_ids, actions, delete_cost, update_cost)
#     612 for cluster_id in cluster_ids:
#     613     prune_actions_by_global_bound(actions, cluster_id)
# --> 614     combined,cartesian, stats = combine_fd_repairs_for_cluster_bt(actions, cluster_id,delete_cost,update_cost)
#     615     if combined:
#     616         leaf = stats.get("leaf_reached", 0)
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:588, in combine_fd_repairs_for_cluster_bt(actions_by_cluster, cluster_id, delete_cost, update_cost)
#     585         combined_ur_ids.difference_update(add_ur)
#     586         combined_dr_ids.difference_update(add_dr)
# --> 588 dfs(0)
#     589 return combined_repairs, total_repairs_possible,stats
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:579, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     576 if rv:
#     577     rv_pairs.append((fd_id, rv))
# --> 579 dfs(i + 1)
#     581 if rv:
#     582     rv_pairs.pop()
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:579, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     576 if rv:
#     577     rv_pairs.append((fd_id, rv))
# --> 579 dfs(i + 1)
#     581 if rv:
#     582     rv_pairs.pop()
#
#     [... skipping similar frames: combine_fd_repairs_for_cluster_bt.<locals>.dfs at line 579 (1 times)]
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:579, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     576 if rv:
#     577     rv_pairs.append((fd_id, rv))
# --> 579 dfs(i + 1)
#     581 if rv:
#     582     rv_pairs.pop()
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:549, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     546 fd_id, _, cand_list = fd_info[i]
#     548 for r in cand_list:
# --> 549     dr_ids = set(r.get("_dr_set", {str(t) for t in r["DR"]}))
#     550     ur_ids = set(r.get("_ur_tids", {parse_tuple_id(u) for u in r["UR"]}))
#     552     if (dr_ids & combined_ur_ids) or (ur_ids & combined_dr_ids):
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:549, in <setcomp>(.0)
#     546 fd_id, _, cand_list = fd_info[i]
#     548 for r in cand_list:
# --> 549     dr_ids = set(r.get("_dr_set", {str(t) for t in r["DR"]}))
#     550     ur_ids = set(r.get("_ur_tids", {parse_tuple_id(u) for u in r["UR"]}))
#     552     if (dr_ids & combined_ur_ids) or (ur_ids & combined_dr_ids):
#
# KeyboardInterrupt:
