# %%
import sys
import os
import warnings
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
from src.database.db_connection import *
from src.database.preparation import *
from src.utilities.step1_simplify_fds import *
from src.utilities.step2_clustering_and_generating_repairs import *
from src.utilities.step3_convert_back_to_db import *
from src.utilities.step4_group_similar_sentences import *
from src.evaluation.metrics import *
from src.database.db_connection import *

# %%
engine = create_engine_for_db()

# %%
fd_constraints = [(['sid', 'university'],['sname', 'address', 'postcode', 'emailid', 'phonenum'])]

# %%
fd_constraints = simplify_FDs(fd_constraints)

# %%
fd_constraints
# Out:
# [(['sid', 'university'], ['sname']),
#  (['sid', 'university'], ['address']),
#  (['sid', 'university'], ['postcode']),
#  (['sid', 'university'], ['emailid']),
#  (['sid', 'university'], ['phonenum'])]

# %%
violation_levels = violation_levels = [
    {'target_violation_fraction': 0.05, 'dups_per_cluster': (1, 1), 'cells_corrupted': (1, 1)},
    {'target_violation_fraction': 0.10, 'dups_per_cluster': (2, 2), 'cells_corrupted': (1, 1)},
    {'target_violation_fraction': 0.20, 'dups_per_cluster': (3, 3), 'cells_corrupted': (1, 2)},
    {'target_violation_fraction': 0.30, 'dups_per_cluster': (4, 4), 'cells_corrupted': (1, 2)},
    {'target_violation_fraction': 0.40, 'dups_per_cluster': (5, 5), 'cells_corrupted': (2, 3)},
    {'target_violation_fraction': 0.50, 'dups_per_cluster': (6, 6), 'cells_corrupted': (2, 3)},
    {'target_violation_fraction': 0.60, 'dups_per_cluster': (7, 7), 'cells_corrupted': (2, 3)},
    {'target_violation_fraction': 0.70, 'dups_per_cluster': (8, 8), 'cells_corrupted': (2, 4)},
    {'target_violation_fraction': 0.80, 'dups_per_cluster': (9, 9), 'cells_corrupted': (3, 4)},
    {'target_violation_fraction': 0.90, 'dups_per_cluster': (10, 10), 'cells_corrupted': (3, 4)},
]


#violation_levels = [{'target_violation_fraction':0.8, 'dups_per_cluster':(3,5), 'cells_corrupted':(3,5)}]
# {'target_violation_fraction':0.5, 'dups_per_cluster':(2,3), 'cells_corrupted':(1,2)},
# {'target_violation_fraction':0.8, 'dups_per_cluster':(3,5), 'cells_corrupted':(2,3)},
# {'target_violation_fraction':1.0, 'dups_per_cluster':(6,10), 'cells_corrupted':(3,5)}]

num_inconsistent_relations = 5

delete_cost = 2
update_cost = 1
eps=1e-9
prob_type = 'COST_BASED'
constraint_hardness = [1.0] * len(fd_constraints)

query_file_name_expected_Prob = "../../../queries/FP/synthetic/Students_truth.sql"
query_file_name_actual_Prob = "../../../queries/FP/synthetic/Students_prob.sql"
algorithm_name = 'PRA'
old_table_name = ''
new_table_name = ''

vio_fracs = []
times_taken = []
num_rvs_used = []
cartesian_possible_list = []
cartesian_computed_list = []
min_cost_actions_list = []
avg_precision_prob_list = []
avg_recall_prob_list = []
avg_coverage_prob_list = []
avg_noise_prob_list = []

# %%
for j,violation_level in enumerate(violation_levels,start=1):
    total_time = 0.0
    total_precision_prob, total_recall_prob,total_coverage_prob, total_noise_prob = 0.0, 0.0, 0.0, 0.0
    total_rvs = 0
    total_cartesian_possible = 0
    total_cartesian_computed = 0
    min_cost_actions_suggested = 0
    
    target_violation_fraction = violation_level['target_violation_fraction']
    dups_per_cluster = violation_level['dups_per_cluster']
    cells_corrupted = violation_level['cells_corrupted']
    for i in range(1, num_inconsistent_relations + 1):
        
        table_name = f"students_{j}_{i}"
        inconsistent_df = pd.read_sql_table(table_name, con=engine, schema="prototype_fp")
        with engine.begin() as connection:
            connection.execute(text("""
            TRUNCATE TABLE prototype_fp.students_prob
            RESTART IDENTITY
            CASCADE;
            """))
            connection.execute(text("""
            UPDATE prototype_fp."_dict"
            SET dict = dictionary('')
            WHERE name = :name;
            """), {"name": "students_dict"})
            

        start = time.perf_counter()
        inconsistent_df = preprocess_data(inconsistent_df)
        actions,cluster_ids,rv_probs = compute_actions(inconsistent_df, fd_constraints, constraint_hardness,delete_cost, update_cost,eps,prob_type)
        all_actions,cartesian_possible,cartesian_computed = min_cost_actions_pruned(cluster_ids,actions,delete_cost,update_cost)
        
        total_cartesian_possible += cartesian_possible
        total_cartesian_computed += cartesian_computed
        min_cost_actions_suggested += len(all_actions)
        
        repaired_versions =  apply_combined_actions(inconsistent_df, all_actions, uuid_col="uuid")
        repaired_versions = pd.concat(repaired_versions, ignore_index=True)
        repaired_versions = repaired_versions.drop(columns=["uuid"])
        rv_probabilities = filter_and_condition_min_cost_rvs(rv_probs, repaired_versions)
        repaired_df = group_similar_rows_together(repaired_versions)
        repaired_df.to_sql('students_prob',engine,schema='prototype_fp',index=False,if_exists='append')
        entries = [f"{k}:{v}" for k, v in rv_probabilities.items()]
        joined = ';'.join(entries)

        update_stmt = f"UPDATE prototype_fp._dict\nSET dict=add(dict, '{joined}')\nWHERE name='students_dict';"
        with engine.begin() as connection:
            connection.execute(text(update_stmt))
        elapsed = time.perf_counter() - start
        total_rvs += len(rv_probabilities)
        total_time += elapsed

        results_Prob,results_with_truth_set_prob = calculate_expected_values(query_file_name_expected_Prob, query_file_name_actual_Prob, algorithm_name,
                                                                             engine,old_table_name,new_table_name)
        precision_prob, recall_prob,coverage_prob, noise_prob = summarize_results(results_Prob)

        print(f"\nViolation Level {j}: Processed inconsistent relation {i} table name: {table_name}")
        print(f"Time taken {elapsed}")
        print(f"Number of RVs used {int(len(rv_probabilities))}")
        print(f"Possible Repair Actions (cartesian product) {int(cartesian_possible)}")
        print(f"Computed Repair Actions {int(cartesian_computed)}")
        print(f"Min cost Repair Actions suggested {int(len(all_actions))}")
        print(f"Precision Probabilistic: {precision_prob:.4f}")
        print(f"Recall Probabilistic: {recall_prob:.4f}")
        print(f"Coverage Probabilistic: {coverage_prob:.4f}")
        print(f"Noise Probabilistic: {noise_prob:.4f}")
        total_precision_prob += precision_prob
        total_recall_prob += recall_prob
        total_coverage_prob += coverage_prob
        total_noise_prob += noise_prob
        
        
    
    avg_time_violation_level = total_time/num_inconsistent_relations
    avg_number_of_rvs = total_rvs/num_inconsistent_relations
    avg_max_repair_actions_possible = total_cartesian_possible/num_inconsistent_relations
    avg_max_repair_actions_computed = total_cartesian_computed/num_inconsistent_relations
    avg_min_cost_actions_suggested = min_cost_actions_suggested/num_inconsistent_relations
    avg_precision_prob = total_precision_prob / num_inconsistent_relations
    avg_recall_prob = total_recall_prob / num_inconsistent_relations
    avg_coverage_prob = total_coverage_prob / num_inconsistent_relations
    avg_noise_prob = total_noise_prob / num_inconsistent_relations
    
    print(f"\nViolation Level {j}: Average time taken {avg_time_violation_level}")
    print(f"Violation Level {j}: Average number of RVs used {int(avg_number_of_rvs)}")
    print(f"Violation Level {j}: Average Max possible repair actions {int(avg_max_repair_actions_possible)}")
    print(f"Violation Level {j}: Average Max computed repair actions {int(avg_max_repair_actions_computed)}")
    print(f"Violation Level {j}: Min cost repair actions suggested {int(avg_min_cost_actions_suggested)}")
    print(f"Average Precision Probabilistic for violation level {j}: {avg_precision_prob:.4f}")
    print(f"Average Recall Probabilistic for violation level {j}: {avg_recall_prob:.4f}")
    print(f"Average Coverage Probabilistic for violation level {j}: {avg_coverage_prob:.4f}")
    print(f"Average Noise Probabilistic for violation level {j}: {avg_noise_prob:.4f}")

    vio_fracs.append(violation_level['target_violation_fraction'])
    times_taken.append(float(avg_time_violation_level))
    num_rvs_used.append(int(avg_number_of_rvs))
    cartesian_possible_list.append(int(avg_max_repair_actions_possible))
    cartesian_computed_list.append(int(avg_max_repair_actions_computed))
    min_cost_actions_list.append(int(avg_min_cost_actions_suggested))
    avg_precision_prob_list.append(float(avg_precision_prob))
    avg_recall_prob_list.append(float(avg_recall_prob))
    avg_coverage_prob_list.append(float(avg_coverage_prob))
    avg_noise_prob_list.append(float(avg_noise_prob))
# Out:
# Violation Level 1: Processed inconsistent relation 1 table name: students_1_1
# Time taken 0.13269060000311583
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9699
# Recall Probabilistic: 0.9622
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0301
#
# Violation Level 1: Processed inconsistent relation 2 table name: students_1_2
# Time taken 0.11533299996517599
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9699
# Recall Probabilistic: 0.9622
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0301
#
# Violation Level 1: Processed inconsistent relation 3 table name: students_1_3
# Time taken 0.10693070001434535
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9688
# Recall Probabilistic: 0.9611
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0312
#
# Violation Level 1: Processed inconsistent relation 4 table name: students_1_4
# Time taken 0.11775539995869622
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9688
# Recall Probabilistic: 0.9611
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0312
#
# Violation Level 1: Processed inconsistent relation 5 table name: students_1_5
# Time taken 0.12401440000394359
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9699
# Recall Probabilistic: 0.9622
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0301
#
# Violation Level 1: Average time taken 0.1193448199890554
# Violation Level 1: Average number of RVs used 2
# Violation Level 1: Average Max possible repair actions 2
# Violation Level 1: Average Max computed repair actions 2
# Violation Level 1: Min cost repair actions suggested 2
# Average Precision Probabilistic for violation level 1: 0.9694
# Average Recall Probabilistic for violation level 1: 0.9618
# Average Coverage Probabilistic for violation level 1: 1.0000
# Average Noise Probabilistic for violation level 1: 0.0306
#
# Violation Level 2: Processed inconsistent relation 1 table name: students_2_1
# Time taken 0.12657659995602444
# Number of RVs used 1
# Possible Repair Actions (cartesian product) 1
# Computed Repair Actions 1
# Min cost Repair Actions suggested 1
# Precision Probabilistic: 0.9692
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0308
#
# Violation Level 2: Processed inconsistent relation 2 table name: students_2_2
# Time taken 0.10850889998255298
# Number of RVs used 3
# Possible Repair Actions (cartesian product) 3
# Computed Repair Actions 3
# Min cost Repair Actions suggested 3
# Precision Probabilistic: 0.9598
# Recall Probabilistic: 0.9496
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0402
#
# Violation Level 2: Processed inconsistent relation 3 table name: students_2_3
# Time taken 0.09957049996592104
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 1
# Min cost Repair Actions suggested 1
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0000
#
# Violation Level 2: Processed inconsistent relation 4 table name: students_2_4
# Time taken 0.09919099998660386
# Number of RVs used 2
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 1
# Min cost Repair Actions suggested 1
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0000
#
# Violation Level 2: Processed inconsistent relation 5 table name: students_2_5
# Time taken 0.12687300000106916
# Number of RVs used 3
# Possible Repair Actions (cartesian product) 3
# Computed Repair Actions 3
# Min cost Repair Actions suggested 3
# Precision Probabilistic: 0.9598
# Recall Probabilistic: 0.9496
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0402
#
# Violation Level 2: Average time taken 0.1121439999784343
# Violation Level 2: Average number of RVs used 2
# Violation Level 2: Average Max possible repair actions 3
# Violation Level 2: Average Max computed repair actions 1
# Violation Level 2: Min cost repair actions suggested 1
# Average Precision Probabilistic for violation level 2: 0.9778
# Average Recall Probabilistic for violation level 2: 0.9798
# Average Coverage Probabilistic for violation level 2: 1.0000
# Average Noise Probabilistic for violation level 2: 0.0222
#
# Violation Level 3: Processed inconsistent relation 1 table name: students_3_1
# Time taken 0.1339103999780491
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 8
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9292
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0708
#
# Violation Level 3: Processed inconsistent relation 2 table name: students_3_2
# Time taken 0.13332220003940165
# Number of RVs used 6
# Possible Repair Actions (cartesian product) 48
# Computed Repair Actions 12
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9359
# Recall Probabilistic: 0.9397
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.0641
#
# Violation Level 3: Processed inconsistent relation 3 table name: students_3_3
# Time taken 0.12565649999305606
# Number of RVs used 7
# Possible Repair Actions (cartesian product) 32
# Computed Repair Actions 8
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0000
#
# Violation Level 3: Processed inconsistent relation 4 table name: students_3_4
# Time taken 0.11659690004307777
# Number of RVs used 5
# Possible Repair Actions (cartesian product) 32
# Computed Repair Actions 8
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0000
#
# Violation Level 3: Processed inconsistent relation 5 table name: students_3_5
# Time taken 0.09967830003006384
# Number of RVs used 3
# Possible Repair Actions (cartesian product) 7
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9252
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0748
#
# Violation Level 3: Average time taken 0.12183286001672969
# Violation Level 3: Average number of RVs used 5
# Violation Level 3: Average Max possible repair actions 25
# Violation Level 3: Average Max computed repair actions 6
# Violation Level 3: Min cost repair actions suggested 2
# Average Precision Probabilistic for violation level 3: 0.9581
# Average Recall Probabilistic for violation level 3: 0.9879
# Average Coverage Probabilistic for violation level 3: 0.9879
# Average Noise Probabilistic for violation level 3: 0.0419
#
# Violation Level 4: Processed inconsistent relation 1 table name: students_4_1
# Time taken 0.14948330004699528
# Number of RVs used 11
# Possible Repair Actions (cartesian product) 56
# Computed Repair Actions 7
# Min cost Repair Actions suggested 3
# Precision Probabilistic: 0.8971
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1029
#
# Violation Level 4: Processed inconsistent relation 2 table name: students_4_2
# Time taken 0.14134740002918988
# Number of RVs used 11
# Possible Repair Actions (cartesian product) 208
# Computed Repair Actions 34
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9261
# Recall Probabilistic: 0.9611
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0739
#
# Violation Level 4: Processed inconsistent relation 3 table name: students_4_3
# Time taken 0.14826029998948798
# Number of RVs used 10
# Possible Repair Actions (cartesian product) 112
# Computed Repair Actions 20
# Min cost Repair Actions suggested 3
# Precision Probabilistic: 0.8957
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1043
#
# Violation Level 4: Processed inconsistent relation 4 table name: students_4_4
# Time taken 0.132488299976103
# Number of RVs used 8
# Possible Repair Actions (cartesian product) 48
# Computed Repair Actions 7
# Min cost Repair Actions suggested 3
# Precision Probabilistic: 0.8846
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1154
#
# Violation Level 4: Processed inconsistent relation 5 table name: students_4_5
# Time taken 0.34054699999978766
# Number of RVs used 13
# Possible Repair Actions (cartesian product) 160
# Computed Repair Actions 27
# Min cost Repair Actions suggested 3
# Precision Probabilistic: 0.9252
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0748
#
# Violation Level 4: Average time taken 0.18242526000831277
# Violation Level 4: Average number of RVs used 10
# Violation Level 4: Average Max possible repair actions 116
# Violation Level 4: Average Max computed repair actions 19
# Violation Level 4: Min cost repair actions suggested 3
# Average Precision Probabilistic for violation level 4: 0.9058
# Average Recall Probabilistic for violation level 4: 0.9922
# Average Coverage Probabilistic for violation level 4: 1.0000
# Average Noise Probabilistic for violation level 4: 0.0942
#
# Violation Level 5: Processed inconsistent relation 1 table name: students_5_1
# Time taken 0.19963930000085384
# Number of RVs used 18
# Possible Repair Actions (cartesian product) 6784
# Computed Repair Actions 111
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.8543
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1457
#
# Violation Level 5: Processed inconsistent relation 2 table name: students_5_2
# Time taken 0.19265669997548684
# Number of RVs used 20
# Possible Repair Actions (cartesian product) 11776
# Computed Repair Actions 191
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.8513
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1487
#
# Violation Level 5: Processed inconsistent relation 3 table name: students_5_3
# Time taken 0.2400952999596484
# Number of RVs used 20
# Possible Repair Actions (cartesian product) 32768
# Computed Repair Actions 448
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.8957
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1043
#
# Violation Level 5: Processed inconsistent relation 4 table name: students_5_4
# Time taken 0.2152388999820687
# Number of RVs used 17
# Possible Repair Actions (cartesian product) 10240
# Computed Repair Actions 190
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.8272
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1728
#
# Violation Level 5: Processed inconsistent relation 5 table name: students_5_5
# Time taken 0.1911676999880001
# Number of RVs used 20
# Possible Repair Actions (cartesian product) 6144
# Computed Repair Actions 128
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.8462
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1538
#
# Violation Level 5: Average time taken 0.20775957998121158
# Violation Level 5: Average number of RVs used 19
# Violation Level 5: Average Max possible repair actions 13542
# Violation Level 5: Average Max computed repair actions 213
# Violation Level 5: Min cost repair actions suggested 4
# Average Precision Probabilistic for violation level 5: 0.8549
# Average Recall Probabilistic for violation level 5: 1.0000
# Average Coverage Probabilistic for violation level 5: 1.0000
# Average Noise Probabilistic for violation level 5: 0.1451
#
# Violation Level 6: Processed inconsistent relation 1 table name: students_6_1
# Time taken 0.22507060004863888
# Number of RVs used 24
# Possible Repair Actions (cartesian product) 14592
# Computed Repair Actions 275
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.7924
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2076
#
# Violation Level 6: Processed inconsistent relation 2 table name: students_6_2
# Time taken 0.24965489999158308
# Number of RVs used 25
# Possible Repair Actions (cartesian product) 35328
# Computed Repair Actions 297
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.7984
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2016
#
# Violation Level 6: Processed inconsistent relation 3 table name: students_6_3
# Time taken 1.0459834999637678
# Number of RVs used 25
# Possible Repair Actions (cartesian product) 34816
# Computed Repair Actions 319
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.7863
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2137
#
# Violation Level 6: Processed inconsistent relation 4 table name: students_6_4
# Time taken 0.24961380002787337
# Number of RVs used 24
# Possible Repair Actions (cartesian product) 25600
# Computed Repair Actions 313
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.7769
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2231
#
# Violation Level 6: Processed inconsistent relation 5 table name: students_6_5
# Time taken 0.3411826000083238
# Number of RVs used 25
# Possible Repair Actions (cartesian product) 36864
# Computed Repair Actions 320
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8036
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1964
#
# Violation Level 6: Average time taken 0.4223010800080374
# Violation Level 6: Average number of RVs used 24
# Violation Level 6: Average Max possible repair actions 29440
# Violation Level 6: Average Max computed repair actions 304
# Violation Level 6: Min cost repair actions suggested 5
# Average Precision Probabilistic for violation level 6: 0.7915
# Average Recall Probabilistic for violation level 6: 1.0000
# Average Coverage Probabilistic for violation level 6: 1.0000
# Average Noise Probabilistic for violation level 6: 0.2085
#
# Violation Level 7: Processed inconsistent relation 1 table name: students_7_1
# Time taken 1.1325618000118993
# Number of RVs used 31
# Possible Repair Actions (cartesian product) 1511424
# Computed Repair Actions 2872
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8423
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1577
#
# Violation Level 7: Processed inconsistent relation 2 table name: students_7_2
# Time taken 0.4425869000260718
# Number of RVs used 29
# Possible Repair Actions (cartesian product) 393216
# Computed Repair Actions 896
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.7293
# Recall Probabilistic: 0.9397
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.2707
#
# Violation Level 7: Processed inconsistent relation 3 table name: students_7_3
# Time taken 0.5248589999973774
# Number of RVs used 30
# Possible Repair Actions (cartesian product) 479232
# Computed Repair Actions 758
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.7511
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2489
#
# Violation Level 7: Processed inconsistent relation 4 table name: students_7_4
# Time taken 0.8166005000239238
# Number of RVs used 32
# Possible Repair Actions (cartesian product) 647168
# Computed Repair Actions 2551
# Min cost Repair Actions suggested 9
# Precision Probabilistic: 0.7392
# Recall Probabilistic: 0.9622
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2608
#
# Violation Level 7: Processed inconsistent relation 5 table name: students_7_5
# Time taken 0.6080483000259846
# Number of RVs used 30
# Possible Repair Actions (cartesian product) 315392
# Computed Repair Actions 760
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.7532
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.2468
#
# Violation Level 7: Average time taken 0.7049313000170514
# Violation Level 7: Average number of RVs used 30
# Violation Level 7: Average Max possible repair actions 669286
# Violation Level 7: Average Max computed repair actions 1567
# Violation Level 7: Min cost repair actions suggested 6
# Average Precision Probabilistic for violation level 7: 0.7630
# Average Recall Probabilistic for violation level 7: 0.9804
# Average Coverage Probabilistic for violation level 7: 0.9879
# Average Noise Probabilistic for violation level 7: 0.2370
#
# Violation Level 8: Processed inconsistent relation 1 table name: students_8_1
# Time taken 3.1914498999831267
# Number of RVs used 36
# Possible Repair Actions (cartesian product) 6422528
# Computed Repair Actions 6144
# Min cost Repair Actions suggested 8
# Precision Probabilistic: 0.6635
# Recall Probabilistic: 0.9611
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.3365
#
# Violation Level 8: Processed inconsistent relation 2 table name: students_8_2
# Time taken 0.8803326999768615
# Number of RVs used 35
# Possible Repair Actions (cartesian product) 5570560
# Computed Repair Actions 2304
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.6704
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.3296
#
# Violation Level 8: Processed inconsistent relation 3 table name: students_8_3
# Time taken 0.8953911000280641
# Number of RVs used 35
# Possible Repair Actions (cartesian product) 16269312
# Computed Repair Actions 1783
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.6881
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.3119
#
# Violation Level 8: Processed inconsistent relation 4 table name: students_8_4
# Time taken 11.775150399946142
# Number of RVs used 40
# Possible Repair Actions (cartesian product) 130547712
# Computed Repair Actions 15360
# Min cost Repair Actions suggested 11
# Precision Probabilistic: 0.6558
# Recall Probabilistic: 0.9210
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.3442
#
# Violation Level 8: Processed inconsistent relation 5 table name: students_8_5
# Time taken 0.8415476999944076
# Number of RVs used 35
# Possible Repair Actions (cartesian product) 8978432
# Computed Repair Actions 1792
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.6886
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.3114
#
# Violation Level 8: Average time taken 3.51677435998572
# Violation Level 8: Average number of RVs used 36
# Violation Level 8: Average Max possible repair actions 33557708
# Violation Level 8: Average Max computed repair actions 5476
# Violation Level 8: Min cost repair actions suggested 8
# Average Precision Probabilistic for violation level 8: 0.6733
# Average Recall Probabilistic for violation level 8: 0.9764
# Average Coverage Probabilistic for violation level 8: 1.0000
# Average Noise Probabilistic for violation level 8: 0.3267
#
# Violation Level 9: Processed inconsistent relation 1 table name: students_9_1
# Time taken 26.176260399981402
# Number of RVs used 40
# Possible Repair Actions (cartesian product) 1266679808
# Computed Repair Actions 13312
# Min cost Repair Actions suggested 8
# Precision Probabilistic: 0.5992
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.4008
#
# Violation Level 9: Processed inconsistent relation 2 table name: students_9_2
# Time taken 41.788524400035385
# Number of RVs used 42
# Possible Repair Actions (cartesian product) 6157238272
# Computed Repair Actions 24064
# Min cost Repair Actions suggested 10
# Precision Probabilistic: 0.6198
# Recall Probabilistic: 1.0000
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.3802
#
# Violation Level 9: Processed inconsistent relation 3 table name: students_9_3
# Time taken 25.215100699977484
# Number of RVs used 40
# Possible Repair Actions (cartesian product) 914358272
# Computed Repair Actions 14848
# Min cost Repair Actions suggested 8
# Precision Probabilistic: 0.5988
# Recall Probabilistic: 0.9397
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.4012
#
# Violation Level 9: Processed inconsistent relation 4 table name: students_9_4
# Time taken 80.5777932999772
# Number of RVs used 41
# Possible Repair Actions (cartesian product) 16357785600
# Computed Repair Actions 35584
# Min cost Repair Actions suggested 9
# Precision Probabilistic: 0.5919
# Recall Probabilistic: 0.9376
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.4081
#
# Violation Level 9: Processed inconsistent relation 5 table name: students_9_5
# Time taken 24.420843400002923
# Number of RVs used 41
# Possible Repair Actions (cartesian product) 23379050496
# Computed Repair Actions 16128
# Min cost Repair Actions suggested 9
# Precision Probabilistic: 0.6173
# Recall Probabilistic: 0.9350
# Coverage Probabilistic: 0.9350
# Noise Probabilistic: 0.3827
#
# Violation Level 9: Average time taken 39.63570443999488
# Violation Level 9: Average number of RVs used 40
# Violation Level 9: Average Max possible repair actions 9615022489
# Violation Level 9: Average Max computed repair actions 20787
# Violation Level 9: Min cost repair actions suggested 8
# Average Precision Probabilistic for violation level 9: 0.6054
# Average Recall Probabilistic for violation level 9: 0.9625
# Average Coverage Probabilistic for violation level 9: 0.9625
# Average Noise Probabilistic for violation level 9: 0.3946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 32
#      30 inconsistent_df = preprocess_data(inconsistent_df)
#      31 actions,cluster_ids,rv_probs = compute_actions(inconsistent_df, fd_constraints, constraint_hardness,delete_cost, update_cost,eps,prob_type)
# ---> 32 all_actions,cartesian_possible,cartesian_computed = min_cost_actions_pruned(cluster_ids,actions,delete_cost,update_cost)
#      34 total_cartesian_possible += cartesian_possible
#      35 total_cartesian_computed += cartesian_computed
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:614, in min_cost_actions_pruned(cluster_ids, actions, delete_cost, update_cost)
#     612 for cluster_id in cluster_ids:
#     613     prune_actions_by_global_bound(actions, cluster_id)
# --> 614     combined,cartesian, stats = combine_fd_repairs_for_cluster_bt(actions, cluster_id,delete_cost,update_cost)
#     615     if combined:
#     616         leaf = stats.get("leaf_reached", 0)
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:588, in combine_fd_repairs_for_cluster_bt(actions_by_cluster, cluster_id, delete_cost, update_cost)
#     585         combined_ur_ids.difference_update(add_ur)
#     586         combined_dr_ids.difference_update(add_dr)
# --> 588 dfs(0)
#     589 return combined_repairs, total_repairs_possible,stats
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:579, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     576 if rv:
#     577     rv_pairs.append((fd_id, rv))
# --> 579 dfs(i + 1)
#     581 if rv:
#     582     rv_pairs.pop()
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:579, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     576 if rv:
#     577     rv_pairs.append((fd_id, rv))
# --> 579 dfs(i + 1)
#     581 if rv:
#     582     rv_pairs.pop()
#
#     [... skipping similar frames: combine_fd_repairs_for_cluster_bt.<locals>.dfs at line 579 (1 times)]
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:579, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     576 if rv:
#     577     rv_pairs.append((fd_id, rv))
# --> 579 dfs(i + 1)
#     581 if rv:
#     582     rv_pairs.pop()
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:549, in combine_fd_repairs_for_cluster_bt.<locals>.dfs(i)
#     546 fd_id, _, cand_list = fd_info[i]
#     548 for r in cand_list:
# --> 549     dr_ids = set(r.get("_dr_set", {str(t) for t in r["DR"]}))
#     550     ur_ids = set(r.get("_ur_tids", {parse_tuple_id(u) for u in r["UR"]}))
#     552     if (dr_ids & combined_ur_ids) or (ur_ids & combined_dr_ids):
#
# File ~\OneDrive\Documents\Thesis-ProbDatabases\repair-approach-prototype\src\utilities\step2_clustering_and_generating_repairs.py:549, in <setcomp>(.0)
#     546 fd_id, _, cand_list = fd_info[i]
#     548 for r in cand_list:
# --> 549     dr_ids = set(r.get("_dr_set", {str(t) for t in r["DR"]}))
#     550     ur_ids = set(r.get("_ur_tids", {parse_tuple_id(u) for u in r["UR"]}))
#     552     if (dr_ids & combined_ur_ids) or (ur_ids & combined_dr_ids):
#
# KeyboardInterrupt:

# %%
vio_fracs

# %%
metrics = [
    ("Time taken (s)", times_taken),
    ("Number of RVs", num_rvs_used),
    ("Possible repair actions (cartesian)", cartesian_possible_list),
    ("Computed repair actions", cartesian_computed_list),
    ("Min-cost actions suggested", min_cost_actions_list),
]

plt.figure()
for label, series in metrics:
    plt.plot(vio_fracs, series, marker='o', label=label)

plt.xlabel("Target violation fraction")
plt.ylabel("Value")
plt.title("PRA metrics vs violation fraction")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(vio_fracs, avg_precision_prob_list, marker='o', label="Avg Precision (Prob)")
plt.plot(vio_fracs, avg_recall_prob_list, marker='o', label="Avg Recall (Prob)")
plt.plot(vio_fracs, avg_coverage_prob_list, marker='o', label="Avg Coverage (Prob)")
plt.plot(vio_fracs, avg_noise_prob_list, marker='o', label="Avg Noise (Prob)")
plt.xlabel("Target violation fraction")
plt.ylabel("Metric value")
plt.title("Probabilistic metrics vs violation fraction")
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# 1) Time vs violation fraction
plt.figure()
plt.plot(vio_fracs, times_taken, marker='o')
plt.xlabel("Target violation fraction")
plt.ylabel("Time taken (s)")
plt.title("Time vs violation fraction")
plt.grid(True)
plt.show()

# 2) #RVs vs violation fraction
plt.figure()
plt.plot(vio_fracs, num_rvs_used, marker='o')
plt.xlabel("Target violation fraction")
plt.ylabel("Number of RVs")
plt.title("#RVs vs violation fraction")
plt.grid(True)
plt.show()

# 3) Cartesian possible vs violation fraction
plt.figure()
plt.plot(vio_fracs, cartesian_possible_list, marker='o')
plt.xlabel("Target violation fraction")
plt.ylabel("Possible repair actions (cartesian)")
plt.title("Possible actions vs violation fraction")
plt.grid(True)
plt.show()

# 4) Cartesian computed vs violation fraction
plt.figure()
plt.plot(vio_fracs, cartesian_computed_list, marker='o')
plt.xlabel("Target violation fraction")
plt.ylabel("Computed repair actions")
plt.title("Computed actions vs violation fraction")
plt.grid(True)
plt.show()

# 5) Min-cost actions suggested vs violation fraction
plt.figure()
plt.plot(vio_fracs, min_cost_actions_list, marker='o')
plt.xlabel("Target violation fraction")
plt.ylabel("Min-cost actions suggested")
plt.title("Min-cost actions vs violation fraction")
plt.grid(True)
plt.show()
