# %%
import sys
import os
import warnings
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
from src.database.db_connection import *
from src.database.preparation import *
from src.utilities.step1_simplify_fds import *
from src.utilities.step2_clustering_and_generating_repairs import *
from src.utilities.step3_convert_back_to_db import *
from src.utilities.step4_group_similar_sentences import *
from src.evaluation.metrics import *
from src.database.db_connection import *

# %%
engine = create_engine_for_db()

# %%
fd_constraints = [(['sid', 'university'],['sname', 'address', 'postcode', 'emailid', 'phonenum'])]

# %%
fd_constraints = simplify_FDs(fd_constraints)

# %%
fd_constraints
# Out:
# [(['sid', 'university'], ['sname']),
#  (['sid', 'university'], ['address']),
#  (['sid', 'university'], ['postcode']),
#  (['sid', 'university'], ['emailid']),
#  (['sid', 'university'], ['phonenum'])]

# %%
violation_levels = violation_levels = [
    {'target_violation_fraction': 0.50, 'dups_per_cluster': (3, 4), 'cells_corrupted': (1, 1)},
    {'target_violation_fraction': 0.50, 'dups_per_cluster': (3, 4), 'cells_corrupted': (2, 2)},
    {'target_violation_fraction': 0.50, 'dups_per_cluster': (3, 4), 'cells_corrupted': (3, 3)},
    {'target_violation_fraction': 0.50, 'dups_per_cluster': (3, 4), 'cells_corrupted': (4, 4)},
    {'target_violation_fraction': 0.50, 'dups_per_cluster': (3, 4), 'cells_corrupted': (5, 5)}
]

num_inconsistent_relations = 10

delete_cost = 2
update_cost = 1
eps=1e-9
prob_type = 'UNIFORM'
constraint_hardness = [1.0] * len(fd_constraints)

query_file_name_expected_Prob = "../../../queries/FP/synthetic/Students_truth.sql"
query_file_name_actual_Prob = "../../../queries/FP/synthetic/Students_prob.sql"
algorithm_name = 'PRA'
old_table_name = ''
new_table_name = ''

vio_fracs = []
times_taken = []
num_rvs_used = []
cartesian_possible_list = []
cartesian_computed_list = []
min_cost_actions_list = []
avg_precision_prob_list = []
avg_recall_prob_list = []
avg_coverage_prob_list = []
avg_noise_prob_list = []

# %%
for j,violation_level in enumerate(violation_levels,start=1):
    total_time = 0.0
    total_precision_prob, total_recall_prob,total_coverage_prob, total_noise_prob = 0.0, 0.0, 0.0, 0.0
    total_rvs = 0
    total_cartesian_possible = 0
    total_cartesian_computed = 0
    min_cost_actions_suggested = 0
    
    target_violation_fraction = violation_level['target_violation_fraction']
    dups_per_cluster = violation_level['dups_per_cluster']
    cells_corrupted = violation_level['cells_corrupted']
    for i in range(1, num_inconsistent_relations + 1):
        table_name = f"students_{j}_{i}"
        inconsistent_df = pd.read_sql_table(table_name, con=engine, schema="prototype_fp_1")
        with engine.begin() as connection:
            connection.execute(text("""
            TRUNCATE TABLE prototype_fp_1.students_prob
            RESTART IDENTITY
            CASCADE;
            """))
            connection.execute(text("""
            UPDATE prototype_fp_1."_dict"
            SET dict = dictionary('')
            WHERE name = :name;
            """), {"name": "students_dict"})

        start = time.perf_counter()
        inconsistent_df = preprocess_data(inconsistent_df)
        actions,cluster_ids,rv_probs = compute_actions(inconsistent_df, fd_constraints, constraint_hardness,delete_cost, update_cost,eps,prob_type)
        all_actions,cartesian_possible,cartesian_computed = min_cost_actions_pruned(cluster_ids,actions,delete_cost,update_cost)
        
        total_cartesian_possible += cartesian_possible
        total_cartesian_computed += cartesian_computed
        min_cost_actions_suggested += len(all_actions)
        
        repaired_versions =  apply_combined_actions(inconsistent_df, all_actions, uuid_col="uuid")
        repaired_versions = pd.concat(repaired_versions, ignore_index=True)
        repaired_versions = repaired_versions.drop(columns=["uuid"])
        #rv_probabilities = filter_and_condition_min_cost_rvs(rv_probs, repaired_versions)
        rv_probabilities = rv_probs
        repaired_df = group_similar_rows_together(repaired_versions)
        repaired_df.to_sql('students_prob',engine,schema='prototype_fp_1',index=False,if_exists='append')
        entries = [f"{k}:{v}" for k, v in rv_probabilities.items()]
        joined = ';'.join(entries)

        update_stmt = f"UPDATE prototype_fp_1._dict\nSET dict=add(dict, '{joined}')\nWHERE name='students_dict';"
        with engine.begin() as connection:
            connection.execute(text(update_stmt))
        elapsed = time.perf_counter() - start
        total_rvs += len(rv_probabilities)
        total_time += elapsed

        results_Prob,results_with_truth_set_prob = calculate_expected_values(query_file_name_expected_Prob, query_file_name_actual_Prob, algorithm_name,
                                                                             engine,old_table_name,new_table_name)
        precision_prob, recall_prob,coverage_prob, noise_prob = summarize_results(results_Prob)

        print(f"\nViolation Level {j}: Processed inconsistent relation {i} table name: {table_name}")
        print(f"Time taken {elapsed}")
        print(f"Number of RVs used {int(len(rv_probabilities))}")
        print(f"Possible Repair Actions (cartesian product) {int(cartesian_possible)}")
        print(f"Computed Repair Actions {int(cartesian_computed)}")
        print(f"Min cost Repair Actions suggested {int(len(all_actions))}")
        print(f"Precision Probabilistic: {precision_prob:.4f}")
        print(f"Recall Probabilistic: {recall_prob:.4f}")
        print(f"Coverage Probabilistic: {coverage_prob:.4f}")
        print(f"Noise Probabilistic: {noise_prob:.4f}")
        total_precision_prob += precision_prob
        total_recall_prob += recall_prob
        total_coverage_prob += coverage_prob
        total_noise_prob += noise_prob
        
        
    
    avg_time_violation_level = total_time/num_inconsistent_relations
    avg_number_of_rvs = total_rvs/num_inconsistent_relations
    avg_max_repair_actions_possible = total_cartesian_possible/num_inconsistent_relations
    avg_max_repair_actions_computed = total_cartesian_computed/num_inconsistent_relations
    avg_min_cost_actions_suggested = min_cost_actions_suggested/num_inconsistent_relations
    avg_precision_prob = total_precision_prob / num_inconsistent_relations
    avg_recall_prob = total_recall_prob / num_inconsistent_relations
    avg_coverage_prob = total_coverage_prob / num_inconsistent_relations
    avg_noise_prob = total_noise_prob / num_inconsistent_relations
    
    print(f"\nViolation Level {j}: Average time taken {avg_time_violation_level}")
    print(f"Violation Level {j}: Average number of RVs used {int(avg_number_of_rvs)}")
    print(f"Violation Level {j}: Average Max possible repair actions {int(avg_max_repair_actions_possible)}")
    print(f"Violation Level {j}: Average Max computed repair actions {int(avg_max_repair_actions_computed)}")
    print(f"Violation Level {j}: Min cost repair actions suggested {int(avg_min_cost_actions_suggested)}")
    print(f"Average Precision Probabilistic for violation level {j}: {avg_precision_prob:.4f}")
    print(f"Average Recall Probabilistic for violation level {j}: {avg_recall_prob:.4f}")
    print(f"Average Coverage Probabilistic for violation level {j}: {avg_coverage_prob:.4f}")
    print(f"Average Noise Probabilistic for violation level {j}: {avg_noise_prob:.4f}")

    vio_fracs.append(violation_level['dups_per_cluster'])
    times_taken.append(float(avg_time_violation_level))
    num_rvs_used.append(int(avg_number_of_rvs))
    cartesian_possible_list.append(int(avg_max_repair_actions_possible))
    cartesian_computed_list.append(int(avg_max_repair_actions_computed))
    min_cost_actions_list.append(int(avg_min_cost_actions_suggested))
    avg_precision_prob_list.append(float(avg_precision_prob))
    avg_recall_prob_list.append(float(avg_recall_prob))
    avg_coverage_prob_list.append(float(avg_coverage_prob))
    avg_noise_prob_list.append(float(avg_noise_prob))
# Out:
# Violation Level 1: Processed inconsistent relation 1 table name: students_1_1
# Time taken 0.08283059997484088
# Number of RVs used 32
# Possible Repair Actions (cartesian product) 38
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9427
# Recall Probabilistic: 0.5768
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0573
#
# Violation Level 1: Processed inconsistent relation 2 table name: students_1_2
# Time taken 0.07462969998596236
# Number of RVs used 32
# Possible Repair Actions (cartesian product) 47
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9181
# Recall Probabilistic: 0.5349
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.0819
#
# Violation Level 1: Processed inconsistent relation 3 table name: students_1_3
# Time taken 0.07424980000359938
# Number of RVs used 30
# Possible Repair Actions (cartesian product) 45
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9421
# Recall Probabilistic: 0.5762
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0579
#
# Violation Level 1: Processed inconsistent relation 4 table name: students_1_4
# Time taken 0.07479630003217608
# Number of RVs used 28
# Possible Repair Actions (cartesian product) 37
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9558
# Recall Probabilistic: 0.5815
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0442
#
# Violation Level 1: Processed inconsistent relation 5 table name: students_1_5
# Time taken 0.0746320000034757
# Number of RVs used 26
# Possible Repair Actions (cartesian product) 28
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9249
# Recall Probabilistic: 0.5868
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0751
#
# Violation Level 1: Processed inconsistent relation 6 table name: students_1_6
# Time taken 0.07530329999281093
# Number of RVs used 32
# Possible Repair Actions (cartesian product) 48
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9151
# Recall Probabilistic: 0.5606
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0849
#
# Violation Level 1: Processed inconsistent relation 7 table name: students_1_7
# Time taken 0.08380469999974594
# Number of RVs used 34
# Possible Repair Actions (cartesian product) 56
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9444
# Recall Probabilistic: 0.5466
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0556
#
# Violation Level 1: Processed inconsistent relation 8 table name: students_1_8
# Time taken 0.08374879998154938
# Number of RVs used 34
# Possible Repair Actions (cartesian product) 60
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9448
# Recall Probabilistic: 0.5673
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0552
#
# Violation Level 1: Processed inconsistent relation 9 table name: students_1_9
# Time taken 0.07512589998077601
# Number of RVs used 28
# Possible Repair Actions (cartesian product) 40
# Computed Repair Actions 5
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9157
# Recall Probabilistic: 0.5755
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0843
#
# Violation Level 1: Processed inconsistent relation 10 table name: students_1_10
# Time taken 0.07448149996344
# Number of RVs used 60
# Possible Repair Actions (cartesian product) 48
# Computed Repair Actions 10
# Min cost Repair Actions suggested 8
# Precision Probabilistic: 0.9047
# Recall Probabilistic: 0.5425
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.0953
#
# Violation Level 1: Average time taken 0.07736025999183767
# Violation Level 1: Average number of RVs used 33
# Violation Level 1: Average Max possible repair actions 44
# Violation Level 1: Average Max computed repair actions 5
# Violation Level 1: Min cost repair actions suggested 5
# Average Precision Probabilistic for violation level 1: 0.9308
# Average Recall Probabilistic for violation level 1: 0.5649
# Average Coverage Probabilistic for violation level 1: 0.9877
# Average Noise Probabilistic for violation level 1: 0.0692
#
# Violation Level 2: Processed inconsistent relation 1 table name: students_2_1
# Time taken 0.09966379997786134
# Number of RVs used 56
# Possible Repair Actions (cartesian product) 326
# Computed Repair Actions 43
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8421
# Recall Probabilistic: 0.5238
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1579
#
# Violation Level 2: Processed inconsistent relation 2 table name: students_2_2
# Time taken 0.11629700002958998
# Number of RVs used 52
# Possible Repair Actions (cartesian product) 240
# Computed Repair Actions 38
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8604
# Recall Probabilistic: 0.5017
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.1396
#
# Violation Level 2: Processed inconsistent relation 3 table name: students_2_3
# Time taken 0.09129910002229735
# Number of RVs used 86
# Possible Repair Actions (cartesian product) 400
# Computed Repair Actions 62
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.9092
# Recall Probabilistic: 0.5078
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0908
#
# Violation Level 2: Processed inconsistent relation 4 table name: students_2_4
# Time taken 0.09089419996598735
# Number of RVs used 64
# Possible Repair Actions (cartesian product) 416
# Computed Repair Actions 54
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8245
# Recall Probabilistic: 0.5016
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1755
#
# Violation Level 2: Processed inconsistent relation 5 table name: students_2_5
# Time taken 0.17463679995853454
# Number of RVs used 62
# Possible Repair Actions (cartesian product) 384
# Computed Repair Actions 52
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8863
# Recall Probabilistic: 0.5095
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1137
#
# Violation Level 2: Processed inconsistent relation 6 table name: students_2_6
# Time taken 0.09119220002321526
# Number of RVs used 64
# Possible Repair Actions (cartesian product) 352
# Computed Repair Actions 50
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8643
# Recall Probabilistic: 0.5043
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1357
#
# Violation Level 2: Processed inconsistent relation 7 table name: students_2_7
# Time taken 0.09154580003814772
# Number of RVs used 70
# Possible Repair Actions (cartesian product) 496
# Computed Repair Actions 64
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8738
# Recall Probabilistic: 0.5077
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1262
#
# Violation Level 2: Processed inconsistent relation 8 table name: students_2_8
# Time taken 0.09165459999348968
# Number of RVs used 76
# Possible Repair Actions (cartesian product) 326
# Computed Repair Actions 55
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8205
# Recall Probabilistic: 0.5343
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1795
#
# Violation Level 2: Processed inconsistent relation 9 table name: students_2_9
# Time taken 0.09167720004916191
# Number of RVs used 72
# Possible Repair Actions (cartesian product) 608
# Computed Repair Actions 84
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8157
# Recall Probabilistic: 0.5064
# Coverage Probabilistic: 0.9350
# Noise Probabilistic: 0.1843
#
# Violation Level 2: Processed inconsistent relation 10 table name: students_2_10
# Time taken 0.08287129999371246
# Number of RVs used 94
# Possible Repair Actions (cartesian product) 704
# Computed Repair Actions 86
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9215
# Recall Probabilistic: 0.5163
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0785
#
# Violation Level 2: Average time taken 0.10217320000519976
# Violation Level 2: Average number of RVs used 69
# Violation Level 2: Average Max possible repair actions 425
# Violation Level 2: Average Max computed repair actions 58
# Violation Level 2: Min cost repair actions suggested 5
# Average Precision Probabilistic for violation level 2: 0.8618
# Average Recall Probabilistic for violation level 2: 0.5114
# Average Coverage Probabilistic for violation level 2: 0.9812
# Average Noise Probabilistic for violation level 2: 0.1382
#
# Violation Level 3: Processed inconsistent relation 1 table name: students_3_1
# Time taken 0.10054809995926917
# Number of RVs used 160
# Possible Repair Actions (cartesian product) 3712
# Computed Repair Actions 206
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8239
# Recall Probabilistic: 0.5058
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1761
#
# Violation Level 3: Processed inconsistent relation 2 table name: students_3_2
# Time taken 0.11652209999738261
# Number of RVs used 160
# Possible Repair Actions (cartesian product) 3712
# Computed Repair Actions 216
# Min cost Repair Actions suggested 9
# Precision Probabilistic: 0.8111
# Recall Probabilistic: 0.4883
# Coverage Probabilistic: 0.8774
# Noise Probabilistic: 0.1889
#
# Violation Level 3: Processed inconsistent relation 3 table name: students_3_3
# Time taken 0.11081730003934354
# Number of RVs used 190
# Possible Repair Actions (cartesian product) 21440
# Computed Repair Actions 403
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8274
# Recall Probabilistic: 0.5030
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1726
#
# Violation Level 3: Processed inconsistent relation 4 table name: students_3_4
# Time taken 0.10816730000078678
# Number of RVs used 130
# Possible Repair Actions (cartesian product) 5120
# Computed Repair Actions 208
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8245
# Recall Probabilistic: 0.4878
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1755
#
# Violation Level 3: Processed inconsistent relation 5 table name: students_3_5
# Time taken 0.09952489996794611
# Number of RVs used 148
# Possible Repair Actions (cartesian product) 12032
# Computed Repair Actions 421
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9119
# Recall Probabilistic: 0.5007
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0881
#
# Violation Level 3: Processed inconsistent relation 6 table name: students_3_6
# Time taken 0.09950939996633679
# Number of RVs used 132
# Possible Repair Actions (cartesian product) 4608
# Computed Repair Actions 149
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8716
# Recall Probabilistic: 0.4965
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1284
#
# Violation Level 3: Processed inconsistent relation 7 table name: students_3_7
# Time taken 0.10802759998477995
# Number of RVs used 86
# Possible Repair Actions (cartesian product) 1984
# Computed Repair Actions 79
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8239
# Recall Probabilistic: 0.4986
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.1761
#
# Violation Level 3: Processed inconsistent relation 8 table name: students_3_8
# Time taken 0.11616680002771318
# Number of RVs used 104
# Possible Repair Actions (cartesian product) 2368
# Computed Repair Actions 202
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.7891
# Recall Probabilistic: 0.5151
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.2109
#
# Violation Level 3: Processed inconsistent relation 9 table name: students_3_9
# Time taken 0.11659220000728965
# Number of RVs used 132
# Possible Repair Actions (cartesian product) 4864
# Computed Repair Actions 156
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8032
# Recall Probabilistic: 0.4922
# Coverage Probabilistic: 0.8774
# Noise Probabilistic: 0.1968
#
# Violation Level 3: Processed inconsistent relation 10 table name: students_3_10
# Time taken 0.15878339996561408
# Number of RVs used 188
# Possible Repair Actions (cartesian product) 24640
# Computed Repair Actions 342
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8303
# Recall Probabilistic: 0.5093
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1697
#
# Violation Level 3: Average time taken 0.11346590999164619
# Violation Level 3: Average number of RVs used 143
# Violation Level 3: Average Max possible repair actions 8448
# Violation Level 3: Average Max computed repair actions 238
# Violation Level 3: Min cost repair actions suggested 5
# Average Precision Probabilistic for violation level 3: 0.8317
# Average Recall Probabilistic for violation level 3: 0.4997
# Average Coverage Probabilistic for violation level 3: 0.9449
# Average Noise Probabilistic for violation level 3: 0.1683
#
# Violation Level 4: Processed inconsistent relation 1 table name: students_4_1
# Time taken 0.11601210001390427
# Number of RVs used 204
# Possible Repair Actions (cartesian product) 33792
# Computed Repair Actions 376
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8153
# Recall Probabilistic: 0.5044
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1847
#
# Violation Level 4: Processed inconsistent relation 2 table name: students_4_2
# Time taken 0.11639799998374656
# Number of RVs used 274
# Possible Repair Actions (cartesian product) 65536
# Computed Repair Actions 616
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8248
# Recall Probabilistic: 0.4872
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1752
#
# Violation Level 4: Processed inconsistent relation 3 table name: students_4_3
# Time taken 0.1171456000301987
# Number of RVs used 248
# Possible Repair Actions (cartesian product) 174592
# Computed Repair Actions 464
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.7947
# Recall Probabilistic: 0.5002
# Coverage Probabilistic: 0.8752
# Noise Probabilistic: 0.2053
#
# Violation Level 4: Processed inconsistent relation 4 table name: students_4_4
# Time taken 0.13290159997995943
# Number of RVs used 226
# Possible Repair Actions (cartesian product) 45056
# Computed Repair Actions 288
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.7991
# Recall Probabilistic: 0.4872
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.2009
#
# Violation Level 4: Processed inconsistent relation 5 table name: students_4_5
# Time taken 0.1408670999808237
# Number of RVs used 320
# Possible Repair Actions (cartesian product) 435712
# Computed Repair Actions 1120
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.7709
# Recall Probabilistic: 0.5002
# Coverage Probabilistic: 0.8748
# Noise Probabilistic: 0.2291
#
# Violation Level 4: Processed inconsistent relation 6 table name: students_4_6
# Time taken 0.12450850004097447
# Number of RVs used 254
# Possible Repair Actions (cartesian product) 123392
# Computed Repair Actions 536
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.7777
# Recall Probabilistic: 0.4958
# Coverage Probabilistic: 0.8124
# Noise Probabilistic: 0.2223
#
# Violation Level 4: Processed inconsistent relation 7 table name: students_4_7
# Time taken 0.2414619000046514
# Number of RVs used 418
# Possible Repair Actions (cartesian product) 589824
# Computed Repair Actions 1264
# Min cost Repair Actions suggested 11
# Precision Probabilistic: 0.7905
# Recall Probabilistic: 0.4958
# Coverage Probabilistic: 0.8774
# Noise Probabilistic: 0.2095
#
# Violation Level 4: Processed inconsistent relation 8 table name: students_4_8
# Time taken 0.1162814000272192
# Number of RVs used 180
# Possible Repair Actions (cartesian product) 24576
# Computed Repair Actions 184
# Min cost Repair Actions suggested 8
# Precision Probabilistic: 0.7862
# Recall Probabilistic: 0.5130
# Coverage Probabilistic: 0.8774
# Noise Probabilistic: 0.2138
#
# Violation Level 4: Processed inconsistent relation 9 table name: students_4_9
# Time taken 0.4430481999879703
# Number of RVs used 408
# Possible Repair Actions (cartesian product) 1712128
# Computed Repair Actions 2232
# Min cost Repair Actions suggested 69
# Precision Probabilistic: 0.7645
# Recall Probabilistic: 0.4915
# Coverage Probabilistic: 0.8774
# Noise Probabilistic: 0.2355
#
# Violation Level 4: Processed inconsistent relation 10 table name: students_4_10
# Time taken 0.153879199991934
# Number of RVs used 262
# Possible Repair Actions (cartesian product) 55296
# Computed Repair Actions 384
# Min cost Repair Actions suggested 13
# Precision Probabilistic: 0.7362
# Recall Probabilistic: 0.5086
# Coverage Probabilistic: 0.8128
# Noise Probabilistic: 0.2638
#
# Violation Level 4: Average time taken 0.1702503600041382
# Violation Level 4: Average number of RVs used 279
# Violation Level 4: Average Max possible repair actions 325990
# Violation Level 4: Average Max computed repair actions 746
# Violation Level 4: Min cost repair actions suggested 13
# Average Precision Probabilistic for violation level 4: 0.7860
# Average Recall Probabilistic for violation level 4: 0.4984
# Average Coverage Probabilistic for violation level 4: 0.8945
# Average Noise Probabilistic for violation level 4: 0.2140
#
# Violation Level 5: Processed inconsistent relation 1 table name: students_5_1
# Time taken 0.27386730001308024
# Number of RVs used 550
# Possible Repair Actions (cartesian product) 5021696
# Computed Repair Actions 2904
# Min cost Repair Actions suggested 20
# Precision Probabilistic: 0.7794
# Recall Probabilistic: 0.5043
# Coverage Probabilistic: 0.8748
# Noise Probabilistic: 0.2206
#
# Violation Level 5: Processed inconsistent relation 2 table name: students_5_2
# Time taken 0.4069764000014402
# Number of RVs used 426
# Possible Repair Actions (cartesian product) 4145152
# Computed Repair Actions 4000
# Min cost Repair Actions suggested 27
# Precision Probabilistic: 0.7948
# Recall Probabilistic: 0.4872
# Coverage Probabilistic: 0.8774
# Noise Probabilistic: 0.2052
#
# Violation Level 5: Processed inconsistent relation 3 table name: students_5_3
# Time taken 0.2912558999960311
# Number of RVs used 328
# Possible Repair Actions (cartesian product) 5308416
# Computed Repair Actions 7192
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8115
# Recall Probabilistic: 0.5000
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1885
#
# Violation Level 5: Processed inconsistent relation 4 table name: students_5_4
# Time taken 0.8106516999541782
# Number of RVs used 468
# Possible Repair Actions (cartesian product) 4636672
# Computed Repair Actions 5160
# Min cost Repair Actions suggested 29
# Precision Probabilistic: 0.7586
# Recall Probabilistic: 0.4872
# Coverage Probabilistic: 0.8103
# Noise Probabilistic: 0.2414
#
# Violation Level 5: Processed inconsistent relation 5 table name: students_5_5
# Time taken 0.391248700034339
# Number of RVs used 518
# Possible Repair Actions (cartesian product) 4366336
# Computed Repair Actions 4232
# Min cost Repair Actions suggested 33
# Precision Probabilistic: 0.7671
# Recall Probabilistic: 0.5000
# Coverage Probabilistic: 0.7825
# Noise Probabilistic: 0.2329
#
# Violation Level 5: Processed inconsistent relation 6 table name: students_5_6
# Time taken 0.39907210000092164
# Number of RVs used 440
# Possible Repair Actions (cartesian product) 9453568
# Computed Repair Actions 5600
# Min cost Repair Actions suggested 14
# Precision Probabilistic: 0.7991
# Recall Probabilistic: 0.4957
# Coverage Probabilistic: 0.7735
# Noise Probabilistic: 0.2009
#
# Violation Level 5: Processed inconsistent relation 7 table name: students_5_7
# Time taken 0.6405608999775723
# Number of RVs used 638
# Possible Repair Actions (cartesian product) 36573184
# Computed Repair Actions 9160
# Min cost Repair Actions suggested 35
# Precision Probabilistic: 0.7841
# Recall Probabilistic: 0.4957
# Coverage Probabilistic: 0.8748
# Noise Probabilistic: 0.2159
#
# Violation Level 5: Processed inconsistent relation 8 table name: students_5_8
# Time taken 0.548691600037273
# Number of RVs used 480
# Possible Repair Actions (cartesian product) 4014080
# Computed Repair Actions 3304
# Min cost Repair Actions suggested 51
# Precision Probabilistic: 0.7316
# Recall Probabilistic: 0.5128
# Coverage Probabilistic: 0.7474
# Noise Probabilistic: 0.2684
#
# Violation Level 5: Processed inconsistent relation 9 table name: students_5_9
# Time taken 0.4745651999837719
# Number of RVs used 436
# Possible Repair Actions (cartesian product) 6782976
# Computed Repair Actions 4416
# Min cost Repair Actions suggested 58
# Precision Probabilistic: 0.7487
# Recall Probabilistic: 0.4915
# Coverage Probabilistic: 0.8145
# Noise Probabilistic: 0.2513
#
# Violation Level 5: Processed inconsistent relation 10 table name: students_5_10
# Time taken 0.28254530002595857
# Number of RVs used 596
# Possible Repair Actions (cartesian product) 6029312
# Computed Repair Actions 4704
# Min cost Repair Actions suggested 15
# Precision Probabilistic: 0.7702
# Recall Probabilistic: 0.5085
# Coverage Probabilistic: 0.8675
# Noise Probabilistic: 0.2298
#
# Violation Level 5: Average time taken 0.4519435100024566
# Violation Level 5: Average number of RVs used 488
# Violation Level 5: Average Max possible repair actions 8633139
# Violation Level 5: Average Max computed repair actions 5067
# Violation Level 5: Min cost repair actions suggested 28
# Average Precision Probabilistic for violation level 5: 0.7745
# Average Recall Probabilistic for violation level 5: 0.4983
# Average Coverage Probabilistic for violation level 5: 0.8362
# Average Noise Probabilistic for violation level 5: 0.2255

# %%
vio_fracs = [1,2,3,4,5]

# %%
metrics = [
    ("Time taken (s)", times_taken),
    ("Number of RVs", num_rvs_used),
    ("Cartesian product of Repair Actions", cartesian_possible_list),
    ("Computed Repair Actions", cartesian_computed_list),
    ("Min-cost Repair Actions Suggested", min_cost_actions_list),
]

# %%
plt.figure()
plt.plot(vio_fracs, avg_precision_prob_list, marker='o', label="Expected Precision")
plt.plot(vio_fracs, avg_recall_prob_list, marker='o', label="Expected Recall")
plt.plot(vio_fracs, avg_coverage_prob_list, marker='o', label="Coverage")
plt.plot(vio_fracs, avg_noise_prob_list, marker='o', label="Noise")
plt.xlabel("Number of FD Violations")
plt.ylabel("Evalution Metric value")
plt.title("Probabilistic Evaluation Metrics vs Number of FD Violations: Uniform")
plt.grid(True)
plt.legend()
plt.xticks(vio_fracs)
plt.show()

# %%
# 1) Time vs violation fraction
plt.figure()
plt.plot(vio_fracs, times_taken, marker='o')
plt.xlabel("Number of FD Violations")
plt.ylabel("Runtime (s)")
plt.title("Runtime vs Number of FD Violations")
plt.grid(True)
plt.xticks(vio_fracs)
plt.show()

# %%
# 2) #RVs vs violation fraction
plt.figure()
plt.plot(vio_fracs, num_rvs_used, marker='o')
plt.xlabel("Number of FD Violations")
plt.ylabel("Number of RVs")
plt.title("Number of RVs vs Number of FD Violations: Uniform Distribution")
plt.grid(True)
plt.xticks(vio_fracs)
plt.show()

# %%
# 3) Cartesian possible vs violation fraction
plt.figure()
plt.plot(vio_fracs, cartesian_possible_list, marker='o')
plt.xlabel("Number of FD Violations")
plt.ylabel("Naive Cartesian product Size of Repair Actions")
plt.title("Naive Cartesian product size vs Number of FD Violations")
plt.grid(True)
plt.xticks(vio_fracs)
plt.show()

# %%
# 4) Cartesian computed vs violation fraction
plt.figure()
plt.plot(vio_fracs, cartesian_computed_list, marker='o')
plt.xlabel("Number of FD Violations")
plt.ylabel("Computed global repair actions")
plt.title("Computed global repair actions vs Number of FD Violations")
plt.grid(True)
plt.xticks(vio_fracs)
plt.show()

# %%
# 5) Min-cost actions suggested vs violation fraction
plt.figure()
plt.plot(vio_fracs, min_cost_actions_list, marker='o')
plt.xlabel("Number of FD Violations")
plt.ylabel("Minimum-cost repair actions")
plt.title("Minimum-cost repair actions vs Number of FD Violations")
plt.grid(True)
plt.xticks(vio_fracs)
plt.show()
