# %%
import sys
import os
import warnings
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
warnings.filterwarnings("ignore")

# %%
from src.database.db_connection import *
from src.database.preparation import *

# %%
file_path = os.path.join(
    os.getcwd(), "..", "..", "..",
    "queries", "FP", "synthetic", "Students.csv"
)
file_path = os.path.abspath(file_path)
df_data = load_csv_to_df(file_path)

# %%
engine = create_engine_for_db()

# %%
df_data.to_sql('students_truth',engine,schema='prototype_fp',index=False,if_exists='replace')
# Out:
# 10

# %%
fd_constraints = [(['sid', 'university'],['sname', 'address', 'postcode', 'emailid', 'phonenum','age'])]

# %%
fd_LHS, fd_RHS = fd_constraints[0]

# %%
fd_LHS
# Out:
# ['sid', 'university']

# %%
fd_RHS
# Out:
# ['sname', 'address', 'postcode', 'emailid', 'phonenum', 'age']

# %%
violation_levels = violation_levels = [
    {'target_violation_fraction': 0.80, 'dups_per_cluster': (4, 4), 'cells_corrupted': (1, 1)},
    {'target_violation_fraction': 0.80, 'dups_per_cluster': (4, 4), 'cells_corrupted': (2, 2)},
    {'target_violation_fraction': 0.80, 'dups_per_cluster': (4, 4), 'cells_corrupted': (3, 3)},
    {'target_violation_fraction': 0.80, 'dups_per_cluster': (4, 4), 'cells_corrupted': (4, 4)},
    {'target_violation_fraction': 0.80, 'dups_per_cluster': (4, 4), 'cells_corrupted': (5, 5)}
]

num_inconsistent_relations = 10

db_persistence = True
holoclean_persistence = True
output_dir_holoclean = r"C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic"
os.makedirs(output_dir_holoclean, exist_ok=True)

# %%
for j,violation_level in enumerate(violation_levels,start=1):
    
    target_violation_fraction = violation_level['target_violation_fraction']
    dups_per_cluster = violation_level['dups_per_cluster']
    cells_corrupted = violation_level['cells_corrupted']

    inconsistent_dfs = generate_corruptions_for_student_data(df_data, fd_LHS, fd_RHS, num_inconsistent_relations, target_violation_frac=target_violation_fraction, 
                                          dups_per_cluster=dups_per_cluster, cells_corrupted=cells_corrupted)
    for (i,inconsistent_df) in enumerate(inconsistent_dfs,start=1):
        table_name = f"students_{j}_{i}"

        if db_persistence:
            inconsistent_df.to_sql(table_name,engine,schema='prototype_fp',index=False,if_exists='replace')
            print(f"Persisted table {table_name} in database")

        if holoclean_persistence:
            csv_path = os.path.join(output_dir_holoclean, f"{table_name}.csv")
            inconsistent_df.to_csv(csv_path, index=False)
            print(f"Wrote CSV: {csv_path}")
# Out:
# Persisted table students_1_1 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_1.csv
# Persisted table students_1_2 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_2.csv
# Persisted table students_1_3 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_3.csv
# Persisted table students_1_4 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_4.csv
# Persisted table students_1_5 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_5.csv
# Persisted table students_1_6 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_6.csv
# Persisted table students_1_7 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_7.csv
# Persisted table students_1_8 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_8.csv
# Persisted table students_1_9 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_9.csv
# Persisted table students_1_10 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_1_10.csv
# Persisted table students_2_1 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_1.csv
# Persisted table students_2_2 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_2.csv
# Persisted table students_2_3 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_3.csv
# Persisted table students_2_4 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_4.csv
# Persisted table students_2_5 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_5.csv
# Persisted table students_2_6 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_6.csv
# Persisted table students_2_7 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_7.csv
# Persisted table students_2_8 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_8.csv
# Persisted table students_2_9 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_9.csv
# Persisted table students_2_10 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_2_10.csv
# Persisted table students_3_1 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_1.csv
# Persisted table students_3_2 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_2.csv
# Persisted table students_3_3 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_3.csv
# Persisted table students_3_4 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_4.csv
# Persisted table students_3_5 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_5.csv
# Persisted table students_3_6 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_6.csv
# Persisted table students_3_7 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_7.csv
# Persisted table students_3_8 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_8.csv
# Persisted table students_3_9 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_9.csv
# Persisted table students_3_10 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_3_10.csv
# Persisted table students_4_1 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_1.csv
# Persisted table students_4_2 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_2.csv
# Persisted table students_4_3 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_3.csv
# Persisted table students_4_4 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_4.csv
# Persisted table students_4_5 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_5.csv
# Persisted table students_4_6 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_6.csv
# Persisted table students_4_7 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_7.csv
# Persisted table students_4_8 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_8.csv
# Persisted table students_4_9 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_9.csv
# Persisted table students_4_10 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_4_10.csv
# Persisted table students_5_1 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_1.csv
# Persisted table students_5_2 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_2.csv
# Persisted table students_5_3 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_3.csv
# Persisted table students_5_4 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_4.csv
# Persisted table students_5_5 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_5.csv
# Persisted table students_5_6 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_6.csv
# Persisted table students_5_7 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_7.csv
# Persisted table students_5_8 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_8.csv
# Persisted table students_5_9 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_9.csv
# Persisted table students_5_10 in database
# Wrote CSV: C:\Users\anush\OneDrive\Documents\Thesis-ProbDatabases\HoloClean\testdata\synthetic\students_5_10.csv
