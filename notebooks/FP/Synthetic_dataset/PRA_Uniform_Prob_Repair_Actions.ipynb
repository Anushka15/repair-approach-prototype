# %%
import sys
import os
import warnings
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
warnings.filterwarnings("ignore")

# %%
from src.database.db_connection import *
from src.database.preparation import *
from src.utilities.step1_simplify_fds import *
from src.utilities.step2_clustering_and_generating_repairs import *
from src.utilities.step3_convert_back_to_db import *
from src.utilities.step4_group_similar_sentences import *
from src.evaluation.metrics import *
from src.database.db_connection import *

# %%
engine = create_engine_for_db()

# %%
fd_constraints = [(['sid', 'university'],['sname', 'address', 'postcode', 'emailid', 'phonenum'])]

# %%
fd_constraints = simplify_FDs(fd_constraints)

# %%
fd_constraints
# Out:
# [(['sid', 'university'], ['sname']),
#  (['sid', 'university'], ['address']),
#  (['sid', 'university'], ['postcode']),
#  (['sid', 'university'], ['emailid']),
#  (['sid', 'university'], ['phonenum'])]

# %%
violation_levels = [
  {'target_violation_fraction': 0.20, 'dups_per_cluster': (1, 1),  'cells_corrupted': (1, 2)},
  {'target_violation_fraction': 0.40, 'dups_per_cluster': (2, 2),  'cells_corrupted': (2, 3)},  
  {'target_violation_fraction': 0.60, 'dups_per_cluster': (4, 4),  'cells_corrupted': (2, 3)},  
  {'target_violation_fraction': 0.80, 'dups_per_cluster': (6, 6),  'cells_corrupted': (3, 4)}  
]

num_inconsistent_relations = 10

delete_cost = 2
update_cost = 1
eps=1e-9
prob_type = 'UNIFORM'
constraint_hardness = [1.0] * len(fd_constraints)

query_file_name_expected_Prob = "../../../queries/FP/synthetic/Students_truth.sql"
query_file_name_actual_Prob = "../../../queries/FP/synthetic/Students_prob.sql"
algorithm_name = 'PRA'
old_table_name = ''
new_table_name = ''

# %%
for j,violation_level in enumerate(violation_levels,start=1):
    total_time = 0.0
    total_precision_prob, total_recall_prob,total_coverage_prob, total_noise_prob = 0.0, 0.0, 0.0, 0.0
    total_rvs = 0
    total_cartesian_possible = 0
    total_cartesian_computed = 0
    min_cost_actions_suggested = 0
    
    target_violation_fraction = violation_level['target_violation_fraction']
    dups_per_cluster = violation_level['dups_per_cluster']
    cells_corrupted = violation_level['cells_corrupted']
    
    for i in range(1, num_inconsistent_relations + 1):
        
        table_name = f"students_{j}_{i}"
        inconsistent_df = pd.read_sql_table(table_name, con=engine, schema="prototype_fp")
        with engine.begin() as connection:
            connection.execute(text("""
            TRUNCATE TABLE prototype_fp.students_prob
            RESTART IDENTITY
            CASCADE;
            """))
            connection.execute(text("""
            UPDATE prototype_fp."_dict"
            SET dict = dictionary('')
            WHERE name = :name;
            """), {"name": "students_dict"})
            

        start = time.perf_counter()
        inconsistent_df = preprocess_data(inconsistent_df)
        actions,cluster_ids,rv_probs = compute_actions(inconsistent_df, fd_constraints, constraint_hardness,delete_cost, update_cost,eps,prob_type)
        all_actions,cartesian_possible,cartesian_computed = min_cost_actions_pruned(cluster_ids,actions,delete_cost,update_cost)
        
        total_cartesian_possible += cartesian_possible
        total_cartesian_computed += cartesian_computed
        min_cost_actions_suggested += len(all_actions)
        
        repaired_versions =  apply_combined_actions(inconsistent_df, all_actions, uuid_col="uuid")
        repaired_versions = pd.concat(repaired_versions, ignore_index=True)
        repaired_versions = repaired_versions.drop(columns=["uuid"])
        #rv_probabilities = filter_and_condition_min_cost_rvs(rv_probs, repaired_versions)
        rv_probabilities = rv_probs
        repaired_df = group_similar_rows_together(repaired_versions)

        repaired_df.to_sql('students_prob',engine,schema='prototype_fp',index=False,if_exists='append')
        entries = [f"{k}:{v}" for k, v in rv_probabilities.items()]
        joined = ';'.join(entries)

        update_stmt = f"UPDATE prototype_fp._dict\nSET dict=add(dict, '{joined}')\nWHERE name='students_dict';"
        with engine.begin() as connection:
            connection.execute(text(update_stmt))
        elapsed = time.perf_counter() - start
        total_rvs += len(rv_probabilities)
        total_time += elapsed

        results_Prob,results_with_truth_set_prob = calculate_expected_values(query_file_name_expected_Prob, query_file_name_actual_Prob, algorithm_name,
                                                                             engine,old_table_name,new_table_name)
        precision_prob, recall_prob,coverage_prob, noise_prob = summarize_results(results_Prob)

        print(f"\nViolation Level {j}: Processed inconsistent relation {i} table name: {table_name}")
        print(f"Time taken {elapsed}")
        print(f"Number of RVs used {int(len(rv_probabilities))}")
        print(f"Possible Repair Actions (cartesian product) {int(cartesian_possible)}")
        print(f"Computed Repair Actions {int(cartesian_computed)}")
        print(f"Min cost Repair Actions suggested {int(len(all_actions))}")
        print(f"Precision Probabilistic: {precision_prob:.4f}")
        print(f"Recall Probabilistic: {recall_prob:.4f}")
        print(f"Coverage Probabilistic: {coverage_prob:.4f}")
        print(f"Noise Probabilistic: {noise_prob:.4f}")
        total_precision_prob += precision_prob
        total_recall_prob += recall_prob
        total_coverage_prob += coverage_prob
        total_noise_prob += noise_prob
    
    avg_time_violation_level = total_time/num_inconsistent_relations
    avg_number_of_rvs = total_rvs/num_inconsistent_relations
    avg_max_repair_actions_possible = total_cartesian_possible/num_inconsistent_relations
    avg_max_repair_actions_computed = total_cartesian_computed/num_inconsistent_relations
    avg_min_cost_actions_suggested = min_cost_actions_suggested/num_inconsistent_relations
    avg_precision_prob = total_precision_prob / num_inconsistent_relations
    avg_recall_prob = total_recall_prob / num_inconsistent_relations
    avg_coverage_prob = total_coverage_prob / num_inconsistent_relations
    avg_noise_prob = total_noise_prob / num_inconsistent_relations

    
    print(f"\nViolation Level {j}: Average time taken {avg_time_violation_level}")
    print(f"Violation Level {j}: Average number of RVs used {int(avg_number_of_rvs)}")
    print(f"Violation Level {j}: Average Max possible repair actions {int(avg_max_repair_actions_possible)}")
    print(f"Violation Level {j}: Average Max computed repair actions {int(avg_max_repair_actions_computed)}")
    print(f"Violation Level {j}: Min cost repair actions suggested {int(avg_min_cost_actions_suggested)}")
    print(f"Average Precision Probabilistic for violation level {j}: {avg_precision_prob:.4f}")
    print(f"Average Recall Probabilistic for violation level {j}: {avg_recall_prob:.4f}")
    print(f"Average Coverage Probabilistic for violation level {j}: {avg_coverage_prob:.4f}")
    print(f"Average Noise Probabilistic for violation level {j}: {avg_noise_prob:.4f}")
# Out:
# Violation Level 1: Processed inconsistent relation 1 table name: students_1_1
# Time taken 0.0750959999859333
# Number of RVs used 8
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9430
# Recall Probabilistic: 0.8673
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0570
#
# Violation Level 1: Processed inconsistent relation 2 table name: students_1_2
# Time taken 0.08856519998516887
# Number of RVs used 16
# Possible Repair Actions (cartesian product) 32
# Computed Repair Actions 12
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9566
# Recall Probabilistic: 0.8086
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0434
#
# Violation Level 1: Processed inconsistent relation 3 table name: students_1_3
# Time taken 0.057147699990309775
# Number of RVs used 8
# Possible Repair Actions (cartesian product) 4
# Computed Repair Actions 4
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9408
# Recall Probabilistic: 0.8620
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0592
#
# Violation Level 1: Processed inconsistent relation 4 table name: students_1_4
# Time taken 0.2744221000466496
# Number of RVs used 12
# Possible Repair Actions (cartesian product) 18
# Computed Repair Actions 8
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9407
# Recall Probabilistic: 0.8260
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0593
#
# Violation Level 1: Processed inconsistent relation 5 table name: students_1_5
# Time taken 0.05836799996905029
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9423
# Recall Probabilistic: 0.9256
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0577
#
# Violation Level 1: Processed inconsistent relation 6 table name: students_1_6
# Time taken 0.06953050009906292
# Number of RVs used 12
# Possible Repair Actions (cartesian product) 18
# Computed Repair Actions 8
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9450
# Recall Probabilistic: 0.8423
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0550
#
# Violation Level 1: Processed inconsistent relation 7 table name: students_1_7
# Time taken 0.05838410009164363
# Number of RVs used 12
# Possible Repair Actions (cartesian product) 18
# Computed Repair Actions 8
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9443
# Recall Probabilistic: 0.8396
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0557
#
# Violation Level 1: Processed inconsistent relation 8 table name: students_1_8
# Time taken 0.057509999955073
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9398
# Recall Probabilistic: 0.9337
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0602
#
# Violation Level 1: Processed inconsistent relation 9 table name: students_1_9
# Time taken 0.05768299999181181
# Number of RVs used 4
# Possible Repair Actions (cartesian product) 2
# Computed Repair Actions 2
# Min cost Repair Actions suggested 2
# Precision Probabilistic: 0.9404
# Recall Probabilistic: 0.9246
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0596
#
# Violation Level 1: Processed inconsistent relation 10 table name: students_1_10
# Time taken 0.07470150000881404
# Number of RVs used 12
# Possible Repair Actions (cartesian product) 18
# Computed Repair Actions 8
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9443
# Recall Probabilistic: 0.8396
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0557
#
# Violation Level 1: Average time taken 0.08714081001235172
# Violation Level 1: Average number of RVs used 9
# Violation Level 1: Average Max possible repair actions 11
# Violation Level 1: Average Max computed repair actions 5
# Violation Level 1: Min cost repair actions suggested 3
# Average Precision Probabilistic for violation level 1: 0.9437
# Average Recall Probabilistic for violation level 1: 0.8669
# Average Coverage Probabilistic for violation level 1: 1.0000
# Average Noise Probabilistic for violation level 1: 0.0563
#
# Violation Level 2: Processed inconsistent relation 1 table name: students_2_1
# Time taken 0.0758241000585258
# Number of RVs used 62
# Possible Repair Actions (cartesian product) 395
# Computed Repair Actions 81
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8746
# Recall Probabilistic: 0.6247
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1254
#
# Violation Level 2: Processed inconsistent relation 2 table name: students_2_2
# Time taken 0.07472160004545003
# Number of RVs used 58
# Possible Repair Actions (cartesian product) 496
# Computed Repair Actions 97
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9485
# Recall Probabilistic: 0.6037
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0515
#
# Violation Level 2: Processed inconsistent relation 3 table name: students_2_3
# Time taken 0.07632550003472716
# Number of RVs used 42
# Possible Repair Actions (cartesian product) 60
# Computed Repair Actions 21
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8772
# Recall Probabilistic: 0.6280
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1228
#
# Violation Level 2: Processed inconsistent relation 4 table name: students_2_4
# Time taken 0.0750218000030145
# Number of RVs used 56
# Possible Repair Actions (cartesian product) 404
# Computed Repair Actions 80
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.8445
# Recall Probabilistic: 0.5989
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.1555
#
# Violation Level 2: Processed inconsistent relation 5 table name: students_2_5
# Time taken 0.07431099994573742
# Number of RVs used 56
# Possible Repair Actions (cartesian product) 264
# Computed Repair Actions 61
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.9106
# Recall Probabilistic: 0.6188
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0894
#
# Violation Level 2: Processed inconsistent relation 6 table name: students_2_6
# Time taken 0.08291320002172142
# Number of RVs used 46
# Possible Repair Actions (cartesian product) 176
# Computed Repair Actions 30
# Min cost Repair Actions suggested 4
# Precision Probabilistic: 0.9736
# Recall Probabilistic: 0.6087
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0264
#
# Violation Level 2: Processed inconsistent relation 7 table name: students_2_7
# Time taken 0.07631129992660135
# Number of RVs used 72
# Possible Repair Actions (cartesian product) 628
# Computed Repair Actions 127
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8615
# Recall Probabilistic: 0.6029
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.1385
#
# Violation Level 2: Processed inconsistent relation 8 table name: students_2_8
# Time taken 0.07479770004283637
# Number of RVs used 42
# Possible Repair Actions (cartesian product) 342
# Computed Repair Actions 69
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8797
# Recall Probabilistic: 0.6442
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1203
#
# Violation Level 2: Processed inconsistent relation 9 table name: students_2_9
# Time taken 0.07454350008629262
# Number of RVs used 68
# Possible Repair Actions (cartesian product) 888
# Computed Repair Actions 132
# Min cost Repair Actions suggested 5
# Precision Probabilistic: 0.9278
# Recall Probabilistic: 0.6063
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0722
#
# Violation Level 2: Processed inconsistent relation 10 table name: students_2_10
# Time taken 0.2910682000219822
# Number of RVs used 46
# Possible Repair Actions (cartesian product) 368
# Computed Repair Actions 77
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8951
# Recall Probabilistic: 0.6228
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1049
#
# Violation Level 2: Average time taken 0.09758379001868889
# Violation Level 2: Average number of RVs used 54
# Violation Level 2: Average Max possible repair actions 402
# Violation Level 2: Average Max computed repair actions 77
# Violation Level 2: Min cost repair actions suggested 5
# Average Precision Probabilistic for violation level 2: 0.8993
# Average Recall Probabilistic for violation level 2: 0.6159
# Average Coverage Probabilistic for violation level 2: 0.9875
# Average Noise Probabilistic for violation level 2: 0.1007
#
# Violation Level 3: Processed inconsistent relation 1 table name: students_3_1
# Time taken 0.09978180006146431
# Number of RVs used 170
# Possible Repair Actions (cartesian product) 3552
# Computed Repair Actions 203
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8436
# Recall Probabilistic: 0.4111
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1564
#
# Violation Level 3: Processed inconsistent relation 2 table name: students_3_2
# Time taken 0.11564879992511123
# Number of RVs used 144
# Possible Repair Actions (cartesian product) 5376
# Computed Repair Actions 175
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8373
# Recall Probabilistic: 0.3934
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.1627
#
# Violation Level 3: Processed inconsistent relation 3 table name: students_3_3
# Time taken 1.2913998999865726
# Number of RVs used 104
# Possible Repair Actions (cartesian product) 2320
# Computed Repair Actions 79
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8521
# Recall Probabilistic: 0.4131
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1479
#
# Violation Level 3: Processed inconsistent relation 4 table name: students_3_4
# Time taken 0.10783699993044138
# Number of RVs used 116
# Possible Repair Actions (cartesian product) 2048
# Computed Repair Actions 135
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.7688
# Recall Probabilistic: 0.3907
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.2312
#
# Violation Level 3: Processed inconsistent relation 5 table name: students_3_5
# Time taken 0.13941019994672388
# Number of RVs used 184
# Possible Repair Actions (cartesian product) 7616
# Computed Repair Actions 228
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8351
# Recall Probabilistic: 0.4078
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.1649
#
# Violation Level 3: Processed inconsistent relation 6 table name: students_3_6
# Time taken 0.11640890000853688
# Number of RVs used 124
# Possible Repair Actions (cartesian product) 4864
# Computed Repair Actions 96
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8887
# Recall Probabilistic: 0.3892
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1113
#
# Violation Level 3: Processed inconsistent relation 7 table name: students_3_7
# Time taken 0.11556289996951818
# Number of RVs used 200
# Possible Repair Actions (cartesian product) 21312
# Computed Repair Actions 677
# Min cost Repair Actions suggested 8
# Precision Probabilistic: 0.7736
# Recall Probabilistic: 0.4002
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.2264
#
# Violation Level 3: Processed inconsistent relation 8 table name: students_3_8
# Time taken 0.12660970003344119
# Number of RVs used 180
# Possible Repair Actions (cartesian product) 3840
# Computed Repair Actions 188
# Min cost Repair Actions suggested 7
# Precision Probabilistic: 0.8495
# Recall Probabilistic: 0.4030
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1505
#
# Violation Level 3: Processed inconsistent relation 9 table name: students_3_9
# Time taken 0.09972739999648184
# Number of RVs used 178
# Possible Repair Actions (cartesian product) 3744
# Computed Repair Actions 223
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8357
# Recall Probabilistic: 0.3976
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1643
#
# Violation Level 3: Processed inconsistent relation 10 table name: students_3_10
# Time taken 0.12321610003709793
# Number of RVs used 204
# Possible Repair Actions (cartesian product) 8064
# Computed Repair Actions 277
# Min cost Repair Actions suggested 6
# Precision Probabilistic: 0.8307
# Recall Probabilistic: 0.3982
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.1693
#
# Violation Level 3: Average time taken 0.23356026998953894
# Violation Level 3: Average number of RVs used 160
# Violation Level 3: Average Max possible repair actions 6273
# Violation Level 3: Average Max computed repair actions 228
# Violation Level 3: Min cost repair actions suggested 6
# Average Precision Probabilistic for violation level 3: 0.8315
# Average Recall Probabilistic for violation level 3: 0.4004
# Average Coverage Probabilistic for violation level 3: 0.9753
# Average Noise Probabilistic for violation level 3: 0.1685
#
# Violation Level 4: Processed inconsistent relation 1 table name: students_4_1
# Time taken 2.366499900002964
# Number of RVs used 3874
# Possible Repair Actions (cartesian product) 266092544
# Computed Repair Actions 22272
# Min cost Repair Actions suggested 19
# Precision Probabilistic: 0.9200
# Recall Probabilistic: 0.2068
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0800
#
# Violation Level 4: Processed inconsistent relation 2 table name: students_4_2
# Time taken 0.3741884999908507
# Number of RVs used 1730
# Possible Repair Actions (cartesian product) 6758400
# Computed Repair Actions 2880
# Min cost Repair Actions suggested 10
# Precision Probabilistic: 0.9123
# Recall Probabilistic: 0.1940
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0877
#
# Violation Level 4: Processed inconsistent relation 3 table name: students_4_3
# Time taken 3.216197400004603
# Number of RVs used 3924
# Possible Repair Actions (cartesian product) 372637696
# Computed Repair Actions 30400
# Min cost Repair Actions suggested 23
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.2111
# Coverage Probabilistic: 1.0000
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Processed inconsistent relation 4 table name: students_4_4
# Time taken 2.4232182999840006
# Number of RVs used 2582
# Possible Repair Actions (cartesian product) 263651328
# Computed Repair Actions 18928
# Min cost Repair Actions suggested 20
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.1940
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Processed inconsistent relation 5 table name: students_4_5
# Time taken 4.808628999977373
# Number of RVs used 4246
# Possible Repair Actions (cartesian product) 227082240
# Computed Repair Actions 44672
# Min cost Repair Actions suggested 33
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.2068
# Coverage Probabilistic: 0.8726
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Processed inconsistent relation 6 table name: students_4_6
# Time taken 2.3411165000870824
# Number of RVs used 2106
# Possible Repair Actions (cartesian product) 313999360
# Computed Repair Actions 19616
# Min cost Repair Actions suggested 22
# Precision Probabilistic: 0.8875
# Recall Probabilistic: 0.1898
# Coverage Probabilistic: 0.8752
# Noise Probabilistic: 0.1125
#
# Violation Level 4: Processed inconsistent relation 7 table name: students_4_7
# Time taken 3.899200899992138
# Number of RVs used 3012
# Possible Repair Actions (cartesian product) 364445696
# Computed Repair Actions 35152
# Min cost Repair Actions suggested 25
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.1897
# Coverage Probabilistic: 0.9376
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Processed inconsistent relation 8 table name: students_4_8
# Time taken 9.924263099906966
# Number of RVs used 3082
# Possible Repair Actions (cartesian product) 5876285440
# Computed Repair Actions 93744
# Min cost Repair Actions suggested 24
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.1940
# Coverage Probabilistic: 0.7803
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Processed inconsistent relation 9 table name: students_4_9
# Time taken 0.6480236999923363
# Number of RVs used 1810
# Possible Repair Actions (cartesian product) 17104896
# Computed Repair Actions 3808
# Min cost Repair Actions suggested 11
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.1983
# Coverage Probabilistic: 0.9397
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Processed inconsistent relation 10 table name: students_4_10
# Time taken 0.8008316999766976
# Number of RVs used 2166
# Possible Repair Actions (cartesian product) 27230208
# Computed Repair Actions 8672
# Min cost Repair Actions suggested 13
# Precision Probabilistic: 1.0000
# Recall Probabilistic: 0.1897
# Coverage Probabilistic: 0.8103
# Noise Probabilistic: 0.0000
#
# Violation Level 4: Average time taken 3.080216899991501
# Violation Level 4: Average number of RVs used 2853
# Violation Level 4: Average Max possible repair actions 773528780
# Violation Level 4: Average Max computed repair actions 28014
# Violation Level 4: Min cost repair actions suggested 20
# Average Precision Probabilistic for violation level 4: 0.9720
# Average Recall Probabilistic for violation level 4: 0.1974
# Average Coverage Probabilistic for violation level 4: 0.9153
# Average Noise Probabilistic for violation level 4: 0.0280
